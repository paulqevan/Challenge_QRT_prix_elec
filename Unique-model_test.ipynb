# %% [markdown]
# # QRT ENS Data Challenge 2023 - Context
#
# Contexte
#
# Une multitude de facteurs influencent le prix de l'electricité au quotidien. Des variations locales du climat pourront à la fois affecter la production et la demande électrique par exemple. Des phénomènes à plus long terme, comme le réchauffement climatique, auront également un impact évident. Des évènements géopolitiques, comme la guerre en Ukraine, peuvent en parallèle faire bouger le prix des matières premières qui sont clefs dans la production d'électricité, sachant que chaque pays s'appuie sur un mix énergétique qui lui est propre (nucléaire, solaire, hydrolique, gaz, charbon, etc). De plus chaque pays peut importer/exporter de l'électricité avec ses voisins au travers de marchés dynamiques, comme en Europe. Ces différents élements rendent assez complexe la modélisation du prix de l'électricité par pays.
#
# But
#
# L'objectif est de modéliser le prix l'électricité à partir de données météorologiques, énergétiques (matières premières) et commerciales pour deux pays européens - la France et l'Allemagne. On soulignera que c'est ici un problème d'explication des prix par d'autres variables concomitantes et non pas un problème de prédiction.
#
# Plus précisément le but est de construire un modèle qui, à partir de ces variables explicatives, renvoie une bonne estimation de la variation journalière du prix de contrats à terme (dits futures) sur l'électricité, en France ou en Allemagne. Ces contrats permettent d'acheter (ou de vendre) une quantité donnée d'électricité à un prix fixé par le contrat et qui sera livrée à une date future spécifiée (maturité du contrat). Les futures sont donc des instruments financiers qui donnent une estimation de la valeur de l'électricité au moment de la maturité du contrat à partir des conditions actuelles du marché - ici, on se restreint à des futures à courte maturité (24h). Soulignons que l'échange de futures sur l'electricité est un marché dynamique en Europe.
#
# Concernant les variables explicatives, les participants auront accès pour chaque pays à des mesures journalières de données météorologiques (température, quantité de pluie et force du vent), de production énergétique (variations des prix de différentes matières premières / énergies) et d'utilisation de l'électricité (consommation, échanges entre ces deux pays, import-export avec le reste de l'Europe).
#
# La fonction de score (métrique) utilisée est la corrélation de Spearman entre la réponse du participant et les variations réelles du prix des futures contenues dans le jeu de données de test.
#
# N'hésitez pas à consulter notre forum dédié et notre page LinkedIn pour plus d'information sur le challenge et sur QRT.
#
# Description des données
#
# Trois jeux de données sont fournis au format csv : les données d'entrainement en entrée X_train et en sortie Y_train, et les données test en entrée X_test.
#
# NB : Les données d'entrée X_train et X_test représentent les même variables explicatives mais sur deux périodes de temps différentes.
#
# La colonne ID de X_train et Y_train est identique, et de même pour les données test. Les données d'entrainement fournissent 1494 lignes, et les données de test en contiennent 654.
#
# Les données d'entrée possèdent 35 colonnes :
#
# ID : Identifiant d'indexe unique, associé à un jour (DAY_ID) et un pays (COUNTRY),
# DAY_ID : Identifiant du jour - les dates ont été annonymisées en préservant la structure des données,
# COUNTRY : Identifiant du pays - DE = Allemagne, FR = France,
#
# et composées ensuite de variations journalières du prix de matières premières,
#
# GAS_RET : Gaz en Europe,
# COAL_RET : Charbon en Europe,
# CARBON_RET : Futures sur les emissions carbone,
#
# de mesures météorologiques (journalières, dans le pays x),
#
# x_TEMP : Temperature,
# x_RAIN : Pluie,
# x_WIND : Vent,
#
# de mesures de productions d'energie (journalière, dans le pays x),
#
# x_GAS : Gaz naturel,
# x_COAL : Charbon,
# x_HYDRO : Hydrolique,
# x_NUCLEAR : Nucléaire,
# x_SOLAR : Photovoltaïque,
# x_WINDPOW : Eolienne,
# x_LIGNITE : Lignite,
#
# et de mesures d'utilisation électrique (journalières, dans le pays x),
#
# x_CONSUMPTON : Electricité totale consommée,
# x_RESIDUAL_LOAD : Electricité consommée après utilisation des énergies renouvelables,
# x_NET_IMPORT: Electricité importée depuis l'Europe,
# x_NET_EXPORT: Electricité exportée vers l'Europe,
# DE_FR_EXCHANGE: Electricité échangée entre Allemagne et France,
# FR_DE_EXCHANGE: Electricité échangée entre France et Allemagne.
#
# Les données en sortie se composent de deux colonnes :
#
# ID : Identifiant unique - le même que celui des données d'entrée,
# TARGET : Variation journalière du prix de futures d'électricité (maturité 24h).
#
# Les solutions envoyées par les participants devront être structurées comme les données en sortie, à savoir un fichier au format csv avec deux colonnes ID and TARGET, avec comme valeurs ID les valeurs correspondantes à la colonne ID de X_test. Un exemple de fichier contenant une solution aléatoire est fourni - Cf. aussi le notebook fourni en materiel supplémentaire.
#
# Description du benchmark
#
# Le benchmark pour ce challenge consiste en une simple régression linéaire, après un léger nettoyage des données : les valeurs manquantes (NaN) ont été remplacées par des zéros et la colonne COUNTRY a été supprimée - en d'autres termes, nous avons utilisé un modèle identique pour la France et l'Allemagne.
#
# Le score public obtenu pour ce benchmark est de 15.86%. Un notebook contenant la génération du benchmark et quelques discussions est disponible en "supplementary files" que vous trouverez sur cette page (colonne de droite).
#
# ## Libraries

# %%
import numpy as np
import pandas as pd
from scipy.stats import spearmanr
from sklearn.linear_model import LinearRegression
import matplotlib.pyplot as plt

X_train = pd.read_csv('X_train.csv')
Y_train = pd.read_csv('Y_train.csv')
X_test = pd.read_csv('X_test.csv')

X_train.head()
# Out:
#      ID  DAY_ID COUNTRY  DE_CONSUMPTION  FR_CONSUMPTION  DE_FR_EXCHANGE  \
# 0  1054     206      FR        0.210099       -0.427458       -0.606523
# 1  2049     501      FR       -0.022399       -1.003452       -0.022063
# 2  1924     687      FR        1.395035        1.978665        1.021305
# 3   297     720      DE       -0.983324       -0.849198       -0.839586
# 4  1101     818      FR        0.143807       -0.617038       -0.924990
#
#    FR_DE_EXCHANGE  DE_NET_EXPORT  FR_NET_EXPORT  DE_NET_IMPORT  ...  \
# 0        0.606523            NaN       0.692860            NaN  ...
# 1        0.022063      -0.573520      -1.130838       0.573520  ...
# 2       -1.021305      -0.622021      -1.682587       0.622021  ...
# 3        0.839586      -0.270870       0.563230       0.270870  ...
# 4        0.924990            NaN       0.990324            NaN  ...
#
#    FR_RESIDUAL_LOAD   DE_RAIN   FR_RAIN   DE_WIND   FR_WIND   DE_TEMP  \
# 0         -0.444661 -0.172680 -0.556356 -0.790823 -0.283160 -1.069070
# 1         -1.183194 -1.240300 -0.770457  1.522331  0.828412  0.437419
# 2          1.947273 -0.480700 -0.313338  0.431134  0.487608  0.684884
# 3         -0.976974 -1.114838 -0.507570 -0.499409 -0.236249  0.350938
# 4         -0.526267 -0.541465 -0.424550 -1.088158 -1.011560  0.614338
#
#     FR_TEMP   GAS_RET  COAL_RET  CARBON_RET
# 0 -0.063404  0.339041  0.124552   -0.002445
# 1  1.831241 -0.659091  0.047114   -0.490365
# 2  0.114836  0.535974  0.743338    0.204952
# 3 -0.417514  0.911652 -0.296168    1.073948
# 4  0.729495  0.245109  1.526606    2.614378
#
# [5 rows x 35 columns]

# %% [markdown]
# # Data processing / Handling missing values

# %%
from sklearn.linear_model import Lasso, Ridge
from sklearn.model_selection import cross_val_score, KFold, GridSearchCV
from sklearn.metrics import make_scorer
from sklearn.preprocessing import OneHotEncoder, StandardScaler
from scipy.stats import spearmanr
import numpy as np

import matplotlib.pyplot as plt

  

X_train = pd.read_csv('X_train.csv')
Y_train = pd.read_csv('Y_train.csv')
X_test = pd.read_csv('X_test.csv')

# Create a time series based on DAY_ID to use for interpolation
X_train_sorted = X_train.sort_values(['COUNTRY', 'DAY_ID'])
X_test_sorted = X_test.sort_values(['COUNTRY', 'DAY_ID'])

# Interpolate missing values using polynomial interpolation for each country
X_train_interpolated = X_train.copy()
X_test_interpolated = X_test.copy()

# Get numeric columns for interpolation
numeric_cols = X_train.columns[3:]

# Interpolate by country using polynomial interpolation
for country in ['DE', 'FR']:
    # Create masks for each country
    train_mask = X_train['COUNTRY'] == country
    test_mask = X_test['COUNTRY'] == country
    
    # For training data - interpolate by polynomial degree 3 where possible
    for col in numeric_cols:
        # Sort by DAY_ID for proper interpolation
        temp_df = X_train_sorted[train_mask].copy()
        # Apply polynomial interpolation
        X_train_interpolated.loc[train_mask, col] = temp_df[col].interpolate(
            method='polynomial', order=3, limit_direction='both'
        )
    
    # For test data - interpolate by polynomial degree 3 where possible
    for col in numeric_cols:
        # Sort by DAY_ID for proper interpolation
        temp_df = X_test_sorted[test_mask].copy()
        # Apply polynomial interpolation
        X_test_interpolated.loc[test_mask, col] = temp_df[col].interpolate(
            method='polynomial', order=3, limit_direction='both'
        )

# Fill any remaining NaN values with 0
X_train_interpolated = X_train_interpolated.fillna(0)
X_test_interpolated = X_test_interpolated.fillna(0)

# Update X_train and X_test with the interpolated values
X_train = X_train_interpolated
X_test = X_test_interpolated


# Create a Spearman correlation scorer
def spearman_score(y_true, y_pred):
    return spearmanr(y_true, y_pred)[0]

spearman_scorer = make_scorer(spearman_score)






# Verify imputation
print("\nRemaining missing values in X_train after imputation:")
print(X_train.isna().sum())
print("\nRemaining missing values in X_test after imputation:")
print(X_test.isna().sum())
# Out:
# Remaining missing values in X_train after imputation:
# ID                  0
# DAY_ID              0
# COUNTRY             0
# DE_CONSUMPTION      0
# FR_CONSUMPTION      0
# DE_FR_EXCHANGE      0
# FR_DE_EXCHANGE      0
# DE_NET_EXPORT       0
# FR_NET_EXPORT       0
# DE_NET_IMPORT       0
# FR_NET_IMPORT       0
# DE_GAS              0
# FR_GAS              0
# DE_COAL             0
# FR_COAL             0
# DE_HYDRO            0
# FR_HYDRO            0
# DE_NUCLEAR          0
# FR_NUCLEAR          0
# DE_SOLAR            0
# FR_SOLAR            0
# DE_WINDPOW          0
# FR_WINDPOW          0
# DE_LIGNITE          0
# DE_RESIDUAL_LOAD    0
# FR_RESIDUAL_LOAD    0
# DE_RAIN             0
# FR_RAIN             0
# DE_WIND             0
# FR_WIND             0
# DE_TEMP             0
# FR_TEMP             0
# GAS_RET             0
# COAL_RET            0
# CARBON_RET          0
# dtype: int64
#
# Remaining missing values in X_test after imputation:
# ID                  0
# DAY_ID              0
# COUNTRY             0
# DE_CONSUMPTION      0
# FR_CONSUMPTION      0
# DE_FR_EXCHANGE      0
# FR_DE_EXCHANGE      0
# DE_NET_EXPORT       0
# FR_NET_EXPORT       0
# DE_NET_IMPORT       0
# FR_NET_IMPORT       0
# DE_GAS              0
# FR_GAS              0
# DE_COAL             0
# FR_COAL             0
# DE_HYDRO            0
# FR_HYDRO            0
# DE_NUCLEAR          0
# FR_NUCLEAR          0
# DE_SOLAR            0
# FR_SOLAR            0
# DE_WINDPOW          0
# FR_WINDPOW          0
# DE_LIGNITE          0
# DE_RESIDUAL_LOAD    0
# FR_RESIDUAL_LOAD    0
# DE_RAIN             0
# FR_RAIN             0
# DE_WIND             0
# FR_WIND             0
# DE_TEMP             0
# FR_TEMP             0
# GAS_RET             0
# COAL_RET            0
# CARBON_RET          0
# dtype: int64
# C:\Users\thoma\AppData\Local\Temp\ipykernel_3244\3229801277.py:36: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   temp_df = X_train_sorted[train_mask].copy()
# C:\Users\thoma\AppData\Local\Temp\ipykernel_3244\3229801277.py:36: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   temp_df = X_train_sorted[train_mask].copy()
# C:\Users\thoma\AppData\Local\Temp\ipykernel_3244\3229801277.py:36: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   temp_df = X_train_sorted[train_mask].copy()
# C:\Users\thoma\AppData\Local\Temp\ipykernel_3244\3229801277.py:36: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   temp_df = X_train_sorted[train_mask].copy()
# C:\Users\thoma\AppData\Local\Temp\ipykernel_3244\3229801277.py:36: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   temp_df = X_train_sorted[train_mask].copy()
# C:\Users\thoma\AppData\Local\Temp\ipykernel_3244\3229801277.py:36: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   temp_df = X_train_sorted[train_mask].copy()
# C:\Users\thoma\AppData\Local\Temp\ipykernel_3244\3229801277.py:36: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   temp_df = X_train_sorted[train_mask].copy()
# C:\Users\thoma\AppData\Local\Temp\ipykernel_3244\3229801277.py:36: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   temp_df = X_train_sorted[train_mask].copy()
# C:\Users\thoma\AppData\Local\Temp\ipykernel_3244\3229801277.py:36: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   temp_df = X_train_sorted[train_mask].copy()
# C:\Users\thoma\AppData\Local\Temp\ipykernel_3244\3229801277.py:36: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   temp_df = X_train_sorted[train_mask].copy()
# C:\Users\thoma\AppData\Local\Temp\ipykernel_3244\3229801277.py:36: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   temp_df = X_train_sorted[train_mask].copy()
# C:\Users\thoma\AppData\Local\Temp\ipykernel_3244\3229801277.py:36: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   temp_df = X_train_sorted[train_mask].copy()
# C:\Users\thoma\AppData\Local\Temp\ipykernel_3244\3229801277.py:36: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   temp_df = X_train_sorted[train_mask].copy()
# C:\Users\thoma\AppData\Local\Temp\ipykernel_3244\3229801277.py:36: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   temp_df = X_train_sorted[train_mask].copy()
# C:\Users\thoma\AppData\Local\Temp\ipykernel_3244\3229801277.py:36: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   temp_df = X_train_sorted[train_mask].copy()
# C:\Users\thoma\AppData\Local\Temp\ipykernel_3244\3229801277.py:36: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   temp_df = X_train_sorted[train_mask].copy()
# C:\Users\thoma\AppData\Local\Temp\ipykernel_3244\3229801277.py:36: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   temp_df = X_train_sorted[train_mask].copy()
# C:\Users\thoma\AppData\Local\Temp\ipykernel_3244\3229801277.py:36: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   temp_df = X_train_sorted[train_mask].copy()
# C:\Users\thoma\AppData\Local\Temp\ipykernel_3244\3229801277.py:36: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   temp_df = X_train_sorted[train_mask].copy()
# C:\Users\thoma\AppData\Local\Temp\ipykernel_3244\3229801277.py:36: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   temp_df = X_train_sorted[train_mask].copy()
# C:\Users\thoma\AppData\Local\Temp\ipykernel_3244\3229801277.py:36: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   temp_df = X_train_sorted[train_mask].copy()
# C:\Users\thoma\AppData\Local\Temp\ipykernel_3244\3229801277.py:36: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   temp_df = X_train_sorted[train_mask].copy()
# C:\Users\thoma\AppData\Local\Temp\ipykernel_3244\3229801277.py:36: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   temp_df = X_train_sorted[train_mask].copy()
# C:\Users\thoma\AppData\Local\Temp\ipykernel_3244\3229801277.py:36: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   temp_df = X_train_sorted[train_mask].copy()
# C:\Users\thoma\AppData\Local\Temp\ipykernel_3244\3229801277.py:36: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   temp_df = X_train_sorted[train_mask].copy()
# C:\Users\thoma\AppData\Local\Temp\ipykernel_3244\3229801277.py:36: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   temp_df = X_train_sorted[train_mask].copy()
# C:\Users\thoma\AppData\Local\Temp\ipykernel_3244\3229801277.py:36: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   temp_df = X_train_sorted[train_mask].copy()
# C:\Users\thoma\AppData\Local\Temp\ipykernel_3244\3229801277.py:36: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   temp_df = X_train_sorted[train_mask].copy()
# C:\Users\thoma\AppData\Local\Temp\ipykernel_3244\3229801277.py:36: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   temp_df = X_train_sorted[train_mask].copy()
# C:\Users\thoma\AppData\Local\Temp\ipykernel_3244\3229801277.py:36: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   temp_df = X_train_sorted[train_mask].copy()
# C:\Users\thoma\AppData\Local\Temp\ipykernel_3244\3229801277.py:36: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   temp_df = X_train_sorted[train_mask].copy()
# C:\Users\thoma\AppData\Local\Temp\ipykernel_3244\3229801277.py:36: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   temp_df = X_train_sorted[train_mask].copy()
# C:\Users\thoma\AppData\Local\Temp\ipykernel_3244\3229801277.py:45: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   temp_df = X_test_sorted[test_mask].copy()
# C:\Users\thoma\AppData\Local\Temp\ipykernel_3244\3229801277.py:45: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   temp_df = X_test_sorted[test_mask].copy()
# C:\Users\thoma\AppData\Local\Temp\ipykernel_3244\3229801277.py:45: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   temp_df = X_test_sorted[test_mask].copy()
# C:\Users\thoma\AppData\Local\Temp\ipykernel_3244\3229801277.py:45: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   temp_df = X_test_sorted[test_mask].copy()
# C:\Users\thoma\AppData\Local\Temp\ipykernel_3244\3229801277.py:45: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   temp_df = X_test_sorted[test_mask].copy()
# C:\Users\thoma\AppData\Local\Temp\ipykernel_3244\3229801277.py:45: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   temp_df = X_test_sorted[test_mask].copy()
# C:\Users\thoma\AppData\Local\Temp\ipykernel_3244\3229801277.py:45: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   temp_df = X_test_sorted[test_mask].copy()
# C:\Users\thoma\AppData\Local\Temp\ipykernel_3244\3229801277.py:45: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   temp_df = X_test_sorted[test_mask].copy()
# C:\Users\thoma\AppData\Local\Temp\ipykernel_3244\3229801277.py:45: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   temp_df = X_test_sorted[test_mask].copy()
# C:\Users\thoma\AppData\Local\Temp\ipykernel_3244\3229801277.py:45: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   temp_df = X_test_sorted[test_mask].copy()
# C:\Users\thoma\AppData\Local\Temp\ipykernel_3244\3229801277.py:45: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   temp_df = X_test_sorted[test_mask].copy()
# C:\Users\thoma\AppData\Local\Temp\ipykernel_3244\3229801277.py:45: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   temp_df = X_test_sorted[test_mask].copy()
# C:\Users\thoma\AppData\Local\Temp\ipykernel_3244\3229801277.py:45: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   temp_df = X_test_sorted[test_mask].copy()
# C:\Users\thoma\AppData\Local\Temp\ipykernel_3244\3229801277.py:45: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   temp_df = X_test_sorted[test_mask].copy()
# C:\Users\thoma\AppData\Local\Temp\ipykernel_3244\3229801277.py:45: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   temp_df = X_test_sorted[test_mask].copy()
# C:\Users\thoma\AppData\Local\Temp\ipykernel_3244\3229801277.py:45: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   temp_df = X_test_sorted[test_mask].copy()
# C:\Users\thoma\AppData\Local\Temp\ipykernel_3244\3229801277.py:45: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   temp_df = X_test_sorted[test_mask].copy()
# C:\Users\thoma\AppData\Local\Temp\ipykernel_3244\3229801277.py:45: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   temp_df = X_test_sorted[test_mask].copy()
# C:\Users\thoma\AppData\Local\Temp\ipykernel_3244\3229801277.py:45: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   temp_df = X_test_sorted[test_mask].copy()
# C:\Users\thoma\AppData\Local\Temp\ipykernel_3244\3229801277.py:45: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   temp_df = X_test_sorted[test_mask].copy()
# C:\Users\thoma\AppData\Local\Temp\ipykernel_3244\3229801277.py:45: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   temp_df = X_test_sorted[test_mask].copy()
# C:\Users\thoma\AppData\Local\Temp\ipykernel_3244\3229801277.py:45: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   temp_df = X_test_sorted[test_mask].copy()
# C:\Users\thoma\AppData\Local\Temp\ipykernel_3244\3229801277.py:45: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   temp_df = X_test_sorted[test_mask].copy()
# C:\Users\thoma\AppData\Local\Temp\ipykernel_3244\3229801277.py:45: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   temp_df = X_test_sorted[test_mask].copy()
# C:\Users\thoma\AppData\Local\Temp\ipykernel_3244\3229801277.py:45: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   temp_df = X_test_sorted[test_mask].copy()
# C:\Users\thoma\AppData\Local\Temp\ipykernel_3244\3229801277.py:45: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   temp_df = X_test_sorted[test_mask].copy()
# C:\Users\thoma\AppData\Local\Temp\ipykernel_3244\3229801277.py:45: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   temp_df = X_test_sorted[test_mask].copy()
# C:\Users\thoma\AppData\Local\Temp\ipykernel_3244\3229801277.py:45: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   temp_df = X_test_sorted[test_mask].copy()
# C:\Users\thoma\AppData\Local\Temp\ipykernel_3244\3229801277.py:45: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   temp_df = X_test_sorted[test_mask].copy()
# C:\Users\thoma\AppData\Local\Temp\ipykernel_3244\3229801277.py:45: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   temp_df = X_test_sorted[test_mask].copy()
# C:\Users\thoma\AppData\Local\Temp\ipykernel_3244\3229801277.py:45: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   temp_df = X_test_sorted[test_mask].copy()
# C:\Users\thoma\AppData\Local\Temp\ipykernel_3244\3229801277.py:45: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   temp_df = X_test_sorted[test_mask].copy()
# C:\Users\thoma\AppData\Local\Temp\ipykernel_3244\3229801277.py:36: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   temp_df = X_train_sorted[train_mask].copy()
# C:\Users\thoma\AppData\Local\Temp\ipykernel_3244\3229801277.py:36: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   temp_df = X_train_sorted[train_mask].copy()
# C:\Users\thoma\AppData\Local\Temp\ipykernel_3244\3229801277.py:36: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   temp_df = X_train_sorted[train_mask].copy()
# C:\Users\thoma\AppData\Local\Temp\ipykernel_3244\3229801277.py:36: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   temp_df = X_train_sorted[train_mask].copy()
# C:\Users\thoma\AppData\Local\Temp\ipykernel_3244\3229801277.py:36: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   temp_df = X_train_sorted[train_mask].copy()
# C:\Users\thoma\AppData\Local\Temp\ipykernel_3244\3229801277.py:36: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   temp_df = X_train_sorted[train_mask].copy()
# C:\Users\thoma\AppData\Local\Temp\ipykernel_3244\3229801277.py:36: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   temp_df = X_train_sorted[train_mask].copy()
# C:\Users\thoma\AppData\Local\Temp\ipykernel_3244\3229801277.py:36: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   temp_df = X_train_sorted[train_mask].copy()
# C:\Users\thoma\AppData\Local\Temp\ipykernel_3244\3229801277.py:36: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   temp_df = X_train_sorted[train_mask].copy()
# C:\Users\thoma\AppData\Local\Temp\ipykernel_3244\3229801277.py:36: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   temp_df = X_train_sorted[train_mask].copy()
# C:\Users\thoma\AppData\Local\Temp\ipykernel_3244\3229801277.py:36: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   temp_df = X_train_sorted[train_mask].copy()
# C:\Users\thoma\AppData\Local\Temp\ipykernel_3244\3229801277.py:36: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   temp_df = X_train_sorted[train_mask].copy()
# C:\Users\thoma\AppData\Local\Temp\ipykernel_3244\3229801277.py:36: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   temp_df = X_train_sorted[train_mask].copy()
# C:\Users\thoma\AppData\Local\Temp\ipykernel_3244\3229801277.py:36: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   temp_df = X_train_sorted[train_mask].copy()
# C:\Users\thoma\AppData\Local\Temp\ipykernel_3244\3229801277.py:36: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   temp_df = X_train_sorted[train_mask].copy()
# C:\Users\thoma\AppData\Local\Temp\ipykernel_3244\3229801277.py:36: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   temp_df = X_train_sorted[train_mask].copy()
# C:\Users\thoma\AppData\Local\Temp\ipykernel_3244\3229801277.py:36: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   temp_df = X_train_sorted[train_mask].copy()
# C:\Users\thoma\AppData\Local\Temp\ipykernel_3244\3229801277.py:36: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   temp_df = X_train_sorted[train_mask].copy()
# C:\Users\thoma\AppData\Local\Temp\ipykernel_3244\3229801277.py:36: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   temp_df = X_train_sorted[train_mask].copy()
# C:\Users\thoma\AppData\Local\Temp\ipykernel_3244\3229801277.py:36: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   temp_df = X_train_sorted[train_mask].copy()
# C:\Users\thoma\AppData\Local\Temp\ipykernel_3244\3229801277.py:36: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   temp_df = X_train_sorted[train_mask].copy()
# C:\Users\thoma\AppData\Local\Temp\ipykernel_3244\3229801277.py:36: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   temp_df = X_train_sorted[train_mask].copy()
# C:\Users\thoma\AppData\Local\Temp\ipykernel_3244\3229801277.py:36: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   temp_df = X_train_sorted[train_mask].copy()
# C:\Users\thoma\AppData\Local\Temp\ipykernel_3244\3229801277.py:36: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   temp_df = X_train_sorted[train_mask].copy()
# C:\Users\thoma\AppData\Local\Temp\ipykernel_3244\3229801277.py:36: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   temp_df = X_train_sorted[train_mask].copy()
# C:\Users\thoma\AppData\Local\Temp\ipykernel_3244\3229801277.py:36: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   temp_df = X_train_sorted[train_mask].copy()
# C:\Users\thoma\AppData\Local\Temp\ipykernel_3244\3229801277.py:36: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   temp_df = X_train_sorted[train_mask].copy()
# C:\Users\thoma\AppData\Local\Temp\ipykernel_3244\3229801277.py:36: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   temp_df = X_train_sorted[train_mask].copy()
# C:\Users\thoma\AppData\Local\Temp\ipykernel_3244\3229801277.py:36: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   temp_df = X_train_sorted[train_mask].copy()
# C:\Users\thoma\AppData\Local\Temp\ipykernel_3244\3229801277.py:36: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   temp_df = X_train_sorted[train_mask].copy()
# C:\Users\thoma\AppData\Local\Temp\ipykernel_3244\3229801277.py:36: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   temp_df = X_train_sorted[train_mask].copy()
# C:\Users\thoma\AppData\Local\Temp\ipykernel_3244\3229801277.py:36: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   temp_df = X_train_sorted[train_mask].copy()
# C:\Users\thoma\AppData\Local\Temp\ipykernel_3244\3229801277.py:45: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   temp_df = X_test_sorted[test_mask].copy()
# C:\Users\thoma\AppData\Local\Temp\ipykernel_3244\3229801277.py:45: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   temp_df = X_test_sorted[test_mask].copy()
# C:\Users\thoma\AppData\Local\Temp\ipykernel_3244\3229801277.py:45: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   temp_df = X_test_sorted[test_mask].copy()
# C:\Users\thoma\AppData\Local\Temp\ipykernel_3244\3229801277.py:45: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   temp_df = X_test_sorted[test_mask].copy()
# C:\Users\thoma\AppData\Local\Temp\ipykernel_3244\3229801277.py:45: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   temp_df = X_test_sorted[test_mask].copy()
# C:\Users\thoma\AppData\Local\Temp\ipykernel_3244\3229801277.py:45: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   temp_df = X_test_sorted[test_mask].copy()
# C:\Users\thoma\AppData\Local\Temp\ipykernel_3244\3229801277.py:45: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   temp_df = X_test_sorted[test_mask].copy()
# C:\Users\thoma\AppData\Local\Temp\ipykernel_3244\3229801277.py:45: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   temp_df = X_test_sorted[test_mask].copy()
# C:\Users\thoma\AppData\Local\Temp\ipykernel_3244\3229801277.py:45: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   temp_df = X_test_sorted[test_mask].copy()
# C:\Users\thoma\AppData\Local\Temp\ipykernel_3244\3229801277.py:45: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   temp_df = X_test_sorted[test_mask].copy()
# C:\Users\thoma\AppData\Local\Temp\ipykernel_3244\3229801277.py:45: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   temp_df = X_test_sorted[test_mask].copy()
# C:\Users\thoma\AppData\Local\Temp\ipykernel_3244\3229801277.py:45: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   temp_df = X_test_sorted[test_mask].copy()
# C:\Users\thoma\AppData\Local\Temp\ipykernel_3244\3229801277.py:45: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   temp_df = X_test_sorted[test_mask].copy()
# C:\Users\thoma\AppData\Local\Temp\ipykernel_3244\3229801277.py:45: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   temp_df = X_test_sorted[test_mask].copy()
# C:\Users\thoma\AppData\Local\Temp\ipykernel_3244\3229801277.py:45: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   temp_df = X_test_sorted[test_mask].copy()
# C:\Users\thoma\AppData\Local\Temp\ipykernel_3244\3229801277.py:45: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   temp_df = X_test_sorted[test_mask].copy()
# C:\Users\thoma\AppData\Local\Temp\ipykernel_3244\3229801277.py:45: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   temp_df = X_test_sorted[test_mask].copy()
# C:\Users\thoma\AppData\Local\Temp\ipykernel_3244\3229801277.py:45: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   temp_df = X_test_sorted[test_mask].copy()
# C:\Users\thoma\AppData\Local\Temp\ipykernel_3244\3229801277.py:45: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   temp_df = X_test_sorted[test_mask].copy()
# C:\Users\thoma\AppData\Local\Temp\ipykernel_3244\3229801277.py:45: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   temp_df = X_test_sorted[test_mask].copy()
# C:\Users\thoma\AppData\Local\Temp\ipykernel_3244\3229801277.py:45: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   temp_df = X_test_sorted[test_mask].copy()
# C:\Users\thoma\AppData\Local\Temp\ipykernel_3244\3229801277.py:45: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   temp_df = X_test_sorted[test_mask].copy()
# C:\Users\thoma\AppData\Local\Temp\ipykernel_3244\3229801277.py:45: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   temp_df = X_test_sorted[test_mask].copy()
# C:\Users\thoma\AppData\Local\Temp\ipykernel_3244\3229801277.py:45: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   temp_df = X_test_sorted[test_mask].copy()
# C:\Users\thoma\AppData\Local\Temp\ipykernel_3244\3229801277.py:45: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   temp_df = X_test_sorted[test_mask].copy()
# C:\Users\thoma\AppData\Local\Temp\ipykernel_3244\3229801277.py:45: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   temp_df = X_test_sorted[test_mask].copy()
# C:\Users\thoma\AppData\Local\Temp\ipykernel_3244\3229801277.py:45: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   temp_df = X_test_sorted[test_mask].copy()
# C:\Users\thoma\AppData\Local\Temp\ipykernel_3244\3229801277.py:45: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   temp_df = X_test_sorted[test_mask].copy()
# C:\Users\thoma\AppData\Local\Temp\ipykernel_3244\3229801277.py:45: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   temp_df = X_test_sorted[test_mask].copy()
# C:\Users\thoma\AppData\Local\Temp\ipykernel_3244\3229801277.py:45: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   temp_df = X_test_sorted[test_mask].copy()
# C:\Users\thoma\AppData\Local\Temp\ipykernel_3244\3229801277.py:45: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   temp_df = X_test_sorted[test_mask].copy()
# C:\Users\thoma\AppData\Local\Temp\ipykernel_3244\3229801277.py:45: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   temp_df = X_test_sorted[test_mask].copy()

# %% [markdown]
# # Features Engineering

# %%
from sklearn.cluster import KMeans



X_train_prep = X_train.copy()
X_test_prep = X_test.copy()

# Create dummy variables for COUNTRY
encoder = OneHotEncoder(sparse=False, drop='first', categories=[['FR', 'DE']])
country_encoded_train = encoder.fit_transform(X_train_prep[['COUNTRY']])
country_encoded_test = encoder.transform(X_test_prep[['COUNTRY']])

# Drop non-feature columns and add encoded country
# X_train_features = X_train_prep.drop(['ID', 'DAY_ID', 'COUNTRY'], axis=1)
X_train_features = X_train_prep.drop(['COUNTRY'], axis=1)
# X_train_features = X_train_prep.drop(['ID', 'DAY_ID'], axis=1)
# X_test_features = X_test_prep.drop(['ID', 'DAY_ID', 'COUNTRY'], axis=1)
X_test_features = X_test_prep.drop(['COUNTRY'], axis=1)


# Add the encoded country column (only DE since FR is the reference)
X_train_features['COUNTRY_DE'] = country_encoded_train
X_test_features['COUNTRY_DE'] = country_encoded_test

# Get target values
y_train = Y_train['TARGET']



# Squared terms for important variables
X_train_features['DE_RESIDUAL_LOAD_SQ'] = X_train_features['DE_RESIDUAL_LOAD']**2
X_test_features['DE_RESIDUAL_LOAD_SQ'] = X_test_features['DE_RESIDUAL_LOAD']**2



# Features variables only for DE
X_train_features['DE_COUNTRY_GAS'] = X_train_features['COUNTRY_DE'] * X_train_features['DE_GAS']
X_test_features['DE_COUNTRY_GAS'] = X_test_features['COUNTRY_DE'] * X_test_features['DE_GAS']

X_train_features['DE_COUNTRY_COAL'] = X_train_features['COUNTRY_DE'] * X_train_features['DE_COAL']
X_test_features['DE_COUNTRY_COAL'] = X_test_features['COUNTRY_DE'] * X_test_features['DE_COAL']


X_train_features['DE_COUNTRY_GAS_RET'] = X_train_features['COUNTRY_DE'] * X_train_features['GAS_RET']
X_test_features['DE_COUNTRY_GAS_RET'] = X_test_features['COUNTRY_DE'] * X_test_features['GAS_RET']


X_train_features['DE_COUNTRY_RESIDUAL'] = X_train_features['COUNTRY_DE'] * X_train_features['DE_RESIDUAL_LOAD']
X_test_features['DE_COUNTRY_RESIDUAL'] = X_test_features['COUNTRY_DE'] * X_test_features['DE_RESIDUAL_LOAD']

X_train_features['DE_COUNTRY_DE_WINDPOW'] = X_train_features['COUNTRY_DE'] * X_train_features['DE_WINDPOW']
X_test_features['DE_COUNTRY_DE_WINDPOW'] = X_test_features['COUNTRY_DE'] * X_test_features['DE_WINDPOW']

X_train_features['DE_COUNTRY_DE_NET_IMPORT'] = X_train_features['COUNTRY_DE'] * X_train_features['DE_NET_IMPORT']
X_test_features['DE_COUNTRY_DE_NET_IMPORT'] = X_test_features['COUNTRY_DE'] * X_test_features['DE_NET_IMPORT']







# Features variables only for FR

# X_train_features['FR_COUNTRY_FR_WINDPOW'] = (1-X_train_features['COUNTRY_DE']) * ( X_train_features['FR_WINDPOW'])








# Calculate correlations with target for all features
correlations = pd.DataFrame({
    'Feature': X_train_features.columns,
    'Pearson_Correlation': [X_train_features[col].corr(y_train) for col in X_train_features.columns],
    'Spearman_Correlation': [X_train_features[col].corr(y_train, method='spearman') for col in X_train_features.columns]
})

# Sort by absolute value of Spearman correlation
correlations['Abs_Spearman'] = correlations['Spearman_Correlation'].abs()
correlations = correlations.sort_values('Abs_Spearman', ascending=False)

# Plot top 20 features by correlation magnitude
plt.figure(figsize=(14, 10))
top_features = correlations.head(42)
colors = ['green' if c > 0 else 'red' for c in top_features['Spearman_Correlation']]
plt.barh(top_features['Feature'], top_features['Spearman_Correlation'], color=colors)
plt.title('Top 20 Features by Spearman Correlation with Target')
plt.xlabel('Correlation Coefficient')
plt.grid(axis='x', linestyle='--', alpha=0.6)
plt.tight_layout()
# Out:
# c:\Users\thoma\anaconda3\Lib\site-packages\sklearn\preprocessing\_encoders.py:868: FutureWarning: `sparse` was renamed to `sparse_output` in version 1.2 and will be removed in 1.4. `sparse_output` is ignored unless you leave `sparse` to its default value.
#   warnings.warn(

# %%
# import numpy as np

# import matplotlib.pyplot as plt

# # Plot the distribution of target values before filtering
# plt.figure(figsize=(12, 6))
# plt.subplot(1, 2, 1)
# plt.hist(y_train, bins=50, alpha=0.7)
# plt.title('Distribution of Target Values (Before Filtering)')
# plt.xlabel('Target Value')
# plt.ylabel('Frequency')

# # Calculate statistics for outlier detection
# mean = y_train.mean()
# std = y_train.std()

# # Define threshold for outliers (3 standard deviations)
# threshold = 3
# lower_bound = mean - threshold * std
# upper_bound = mean + threshold * std

# print(f"Mean: {mean:.4f}")
# print(f"Standard Deviation: {std:.4f}")
# print(f"Lower bound: {lower_bound:.4f}")
# print(f"Upper bound: {upper_bound:.4f}")

# # Create a mask for values within bounds
# inlier_mask = (y_train >= lower_bound) & (y_train <= upper_bound)

# # Count outliers
# outliers_count = (~inlier_mask).sum()
# print(f"Number of outliers detected: {outliers_count} ({outliers_count/len(y_train)*100:.2f}%)")

# # Filter the datasets to remove outliers
# X_train_filtered = X_train_features[inlier_mask]
# y_train_filtered = y_train[inlier_mask]

# # Update the variables for the rest of the notebook
# X_train_features = X_train_filtered
# y_train = y_train_filtered

# # Plot the distribution after filtering
# plt.subplot(1, 2, 2)
# plt.hist(y_train, bins=50, alpha=0.7)
# plt.title('Distribution of Target Values (After Filtering)')
# plt.xlabel('Target Value')
# plt.ylabel('Frequency')
# plt.tight_layout()
# plt.show()

# print(f"Original dataset size: {len(inlier_mask)}")
# print(f"Filtered dataset size: {len(y_train)}")
# print(f"Removed {len(inlier_mask) - len(y_train)} samples")

# %% [markdown]
# # Specify Country

# %%
# # Filter data for just the country Germany (DE)
# # Create masks for Germany
# DE_mask = X_train_features['COUNTRY_DE'] == 1


# # german_indices = X_train_features[DE_mask].index

# # Create filtered dataframes
# X_train_features = X_train_features[DE_mask.values]
# y_train = y_train[DE_mask.values]

# # y_train = Y_train.loc[Y_train['ID'].isin(X_train['ID'][german_indices]), 'TARGET']

# y_train.describe()

# %% [markdown]
# # Regression Lasso/ridge

# %%
# Apply StandardScaler to features
scaler = StandardScaler()
X_train_scaled = scaler.fit_transform(X_train_features)
X_test_scaled = scaler.transform(X_test_features)

# Define column names for the scaled data
feature_names = X_train_features.columns


# Define cross-validation strategy
kf = KFold(n_splits=5, shuffle=True, random_state=1)

# LASSO Regression with Grid Search
alphas_lasso = [0.0001, 0.001, 0.01, 0.1, 0.5, 1, 5, 10]
param_grid_lasso = {'alpha': alphas_lasso}

lasso_grid = GridSearchCV(
    Lasso(max_iter=10000, random_state=1),
    param_grid_lasso,
    cv=kf,
    scoring=spearman_scorer
)
lasso_grid.fit(X_train_scaled, y_train)

print(f"Best Lasso alpha: {lasso_grid.best_params_['alpha']}")
print(f"Best Lasso cross-validation score: {lasso_grid.best_score_:.4f}")

# Ridge Regression with Grid Search
# alphas_ridge = [0.0001, 0.001, 0.01, 0.1, 1, 10, 100, 1000]
alphas_ridge = [200, 500, 1000, 1500, 2000]
param_grid_ridge = {'alpha': alphas_ridge}

ridge_grid = GridSearchCV(
    Ridge(random_state=1),
    param_grid_ridge,
    cv=kf,
    scoring=spearman_scorer
)
ridge_grid.fit(X_train_scaled, y_train)

print(f"Best Ridge alpha: {ridge_grid.best_params_['alpha']}")
print(f"Best Ridge cross-validation score: {ridge_grid.best_score_:.4f}")

# Fit final Lasso model with best alpha
final_lasso = Lasso(alpha=lasso_grid.best_params_['alpha'], max_iter=10000, random_state=42)
final_lasso.fit(X_train_scaled, y_train)

final_ridge = Ridge(alpha=ridge_grid.best_params_['alpha'], max_iter=10000, random_state=42)
final_ridge.fit(X_train_scaled, y_train)

# Get feature importance from Lasso coefficients
lasso_coef = pd.DataFrame({
    'Feature': feature_names,
    'Coefficient': final_lasso.coef_
}).sort_values('Coefficient', key=lambda x: abs(x), ascending=False)

# Plot Lasso coefficients (top 20 by magnitude)
plt.figure(figsize=(12, 8))
lasso_top20 = lasso_coef.head(20)
colors = ['green' if c > 0 else 'red' for c in lasso_top20['Coefficient']]
plt.barh(lasso_top20['Feature'], lasso_top20['Coefficient'], color=colors)
plt.title('Lasso: Top 20 Features by Coefficient Magnitude')
plt.xlabel('Coefficient Value')
plt.gca().invert_yaxis()
plt.grid(axis='x', linestyle='--', alpha=0.6)
plt.tight_layout()
plt.show()

# Count non-zero coefficients
n_selected = np.sum(final_lasso.coef_ != 0)
print(f"Lasso selected {n_selected} features out of {len(feature_names)}")

# Print features with non-zero coefficients
selected_features = lasso_coef[lasso_coef['Coefficient'] != 0]
print("Selected features by Lasso:")
print(selected_features)
# Out:
# c:\Users\thoma\anaconda3\Lib\site-packages\scipy\stats\_stats_py.py:5445: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(stats.ConstantInputWarning(warn_msg))
# c:\Users\thoma\anaconda3\Lib\site-packages\scipy\stats\_stats_py.py:5445: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(stats.ConstantInputWarning(warn_msg))
# c:\Users\thoma\anaconda3\Lib\site-packages\scipy\stats\_stats_py.py:5445: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(stats.ConstantInputWarning(warn_msg))
# c:\Users\thoma\anaconda3\Lib\site-packages\scipy\stats\_stats_py.py:5445: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(stats.ConstantInputWarning(warn_msg))
# c:\Users\thoma\anaconda3\Lib\site-packages\scipy\stats\_stats_py.py:5445: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(stats.ConstantInputWarning(warn_msg))
# c:\Users\thoma\anaconda3\Lib\site-packages\scipy\stats\_stats_py.py:5445: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(stats.ConstantInputWarning(warn_msg))
# c:\Users\thoma\anaconda3\Lib\site-packages\scipy\stats\_stats_py.py:5445: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(stats.ConstantInputWarning(warn_msg))
# c:\Users\thoma\anaconda3\Lib\site-packages\scipy\stats\_stats_py.py:5445: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(stats.ConstantInputWarning(warn_msg))
# c:\Users\thoma\anaconda3\Lib\site-packages\scipy\stats\_stats_py.py:5445: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(stats.ConstantInputWarning(warn_msg))
# c:\Users\thoma\anaconda3\Lib\site-packages\scipy\stats\_stats_py.py:5445: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(stats.ConstantInputWarning(warn_msg))
# c:\Users\thoma\anaconda3\Lib\site-packages\scipy\stats\_stats_py.py:5445: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(stats.ConstantInputWarning(warn_msg))
# c:\Users\thoma\anaconda3\Lib\site-packages\scipy\stats\_stats_py.py:5445: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(stats.ConstantInputWarning(warn_msg))
# c:\Users\thoma\anaconda3\Lib\site-packages\scipy\stats\_stats_py.py:5445: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(stats.ConstantInputWarning(warn_msg))
# c:\Users\thoma\anaconda3\Lib\site-packages\scipy\stats\_stats_py.py:5445: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(stats.ConstantInputWarning(warn_msg))
# c:\Users\thoma\anaconda3\Lib\site-packages\scipy\stats\_stats_py.py:5445: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(stats.ConstantInputWarning(warn_msg))
# c:\Users\thoma\anaconda3\Lib\site-packages\scipy\stats\_stats_py.py:5445: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(stats.ConstantInputWarning(warn_msg))
# c:\Users\thoma\anaconda3\Lib\site-packages\scipy\stats\_stats_py.py:5445: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(stats.ConstantInputWarning(warn_msg))
# c:\Users\thoma\anaconda3\Lib\site-packages\scipy\stats\_stats_py.py:5445: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(stats.ConstantInputWarning(warn_msg))
# c:\Users\thoma\anaconda3\Lib\site-packages\scipy\stats\_stats_py.py:5445: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(stats.ConstantInputWarning(warn_msg))
# c:\Users\thoma\anaconda3\Lib\site-packages\scipy\stats\_stats_py.py:5445: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(stats.ConstantInputWarning(warn_msg))
# c:\Users\thoma\anaconda3\Lib\site-packages\sklearn\model_selection\_search.py:952: UserWarning: One or more of the test scores are non-finite: [0.22982881 0.23458444 0.24164836 0.22030057        nan        nan
#         nan        nan]
#   warnings.warn(
# Best Lasso alpha: 0.01
# Best Lasso cross-validation score: 0.2416
# Best Ridge alpha: 500
# Best Ridge cross-validation score: 0.2474
# Lasso selected 22 features out of 42
# Selected features by Lasso:
#                      Feature  Coefficient
# 41  DE_COUNTRY_DE_NET_IMPORT     0.096422
# 4             DE_FR_EXCHANGE     0.084872
# 6              DE_NET_EXPORT    -0.081045
# 39       DE_COUNTRY_RESIDUAL     0.079946
# 35       DE_RESIDUAL_LOAD_SQ    -0.075346
# 21                FR_WINDPOW    -0.067492
# 24          FR_RESIDUAL_LOAD     0.050686
# 22                DE_LIGNITE    -0.050203
# 2             DE_CONSUMPTION    -0.031544
# 19                  FR_SOLAR    -0.026198
# 18                  DE_SOLAR    -0.026157
# 31                   GAS_RET     0.022864
# 15                  FR_HYDRO     0.022697
# 14                  DE_HYDRO     0.022268
# 28                   FR_WIND     0.021186
# 0                         ID    -0.014212
# 25                   DE_RAIN    -0.010851
# 17                FR_NUCLEAR     0.010470
# 38        DE_COUNTRY_GAS_RET    -0.007616
# 33                CARBON_RET     0.006653
# 26                   FR_RAIN    -0.005438
# 32                  COAL_RET    -0.003152

# %%
# Filter X_train_features and X_test_features to keep only the features 
# selected by Lasso (non-zero coefficients)
selected_feature_names = lasso_coef[lasso_coef['Coefficient'] != 0]['Feature'].values

# Create new dataframes with only selected features
X_train_features = X_train_features[selected_feature_names]
X_test_features = X_test_features[selected_feature_names]




# # Create a copy of y_train to avoid modifying the original
# y_train_log = y_train.copy()

# # Handle negative values by using sign(y) * log(1 + abs(y))
# # This preserves the sign while applying a logarithmic transformation
# y_train = np.sign(y_train) * np.log1p(np.abs(y_train))

# %% [markdown]
# # Hyperparameters tuning

# %%
from sklearn.ensemble import RandomForestRegressor
from sklearn.model_selection import cross_val_score, KFold
from sklearn.metrics import make_scorer
from sklearn.preprocessing import OneHotEncoder
from scipy.stats import spearmanr

# Define parameter grid for CatBoost
# param_grid = {
#     'iterations': [50, 100, 200],
#     'learning_rate': [0.005, 0.01, 0.02],
#     'depth': [6, 8, 10],
#     'l2_leaf_reg': [2, 3, 4],
#     'subsample': [0.7, 0.8, 0.9]
# }

# Define parameter grid for LightGBM
param_grid = {
    'n_estimators': [50, 100, 200],
    'learning_rate': [0.01, 0.05, 0.1],
    'max_depth': [4, 6, 8],
    'num_leaves': [15, 31, 63],
    'subsample': [0.6, 0.8, 1.0],
    'colsample_bytree': [0.6, 0.8, 1.0],
    'min_child_samples': [5, 10, 20],
    'verbose': [-1]
}

# Define cross-validation strategy
kf = KFold(n_splits=5, shuffle=True, random_state=1)

# Create RandomizedSearchCV to find optimal parameters
search = RandomizedSearchCV(
    LGBMRegressor(random_seed=42, verbose=False),
    param_grid,
    n_iter=100,  # Number of parameter settings sampled
    scoring=spearman_scorer,
    cv=kf,
    random_state=42,
    n_jobs=-1,
    
)

# Fit the model
search.fit(X_train_features, y_train)

# Print best parameters and score
print("Best parameters found:")
print(search.best_params_)
print(f"Best cross-validation score: {search.best_score_:.4f}")
# Out:
# Best parameters found:
# {'verbose': -1, 'subsample': 0.8, 'num_leaves': 31, 'n_estimators': 200, 'min_child_samples': 10, 'max_depth': 8, 'learning_rate': 0.01, 'colsample_bytree': 0.6}
# Best cross-validation score: 0.2438

# %% [markdown]
# RandomForest

# %%
import optuna
from sklearn.ensemble import RandomForestRegressor
from sklearn.model_selection import cross_val_score, KFold
from sklearn.metrics import make_scorer
from sklearn.preprocessing import OneHotEncoder
from scipy.stats import spearmanr
from sklearn.model_selection import cross_val_score, KFold
from sklearn.metrics import make_scorer


# Define the objective function for Optuna
def objective(trial):
    # Define hyperparameters to optimize
    n_estimators = trial.suggest_int('n_estimators', 100, 1000, step=100)
    max_depth = trial.suggest_int('max_depth', 5, 30, step=5)
    min_samples_split = trial.suggest_int('min_samples_split', 2, 10)
    min_samples_leaf = trial.suggest_int('min_samples_leaf', 1, 5)
    max_features = trial.suggest_categorical('max_features', ['sqrt', 'log2', None])
    bootstrap = trial.suggest_categorical('bootstrap', [True, False])
    
    # Create RandomForest model with the suggested hyperparameters
    rf_model = RandomForestRegressor(
        n_estimators=n_estimators,
        max_depth=max_depth,
        min_samples_split=min_samples_split,
        min_samples_leaf=min_samples_leaf,
        max_features=max_features,
        bootstrap=bootstrap,
        random_state=42,
        n_jobs=-1
    )
    
    # Use 5-fold cross-validation
    kf = KFold(n_splits=5, shuffle=True, random_state=42)
    
    # Calculate the cross-validation score using Spearman correlation
    cv_scores = cross_val_score(
        rf_model, 
        X_train_features, 
        y_train,
        cv=kf,
    )
    
    # Return the mean score to maximize
    return cv_scores.mean()

# Create an Optuna study to maximize the objective function
study = optuna.create_study(direction='maximize')

# Run the optimization with 100 trials
study.optimize(objective, n_trials=100)

# Print the best parameters and score
print("Best parameters:", study.best_params)
print(f"Best cross-validation score: {study.best_value:.4f}")
# Out:
# [I 2025-05-23 02:15:50,600] A new study created in memory with name: no-name-49a72729-6c21-415c-aafd-916a3699375f
# [I 2025-05-23 02:16:00,211] Trial 0 finished with value: 0.016619358470890622 and parameters: {'n_estimators': 700, 'max_depth': 25, 'min_samples_split': 9, 'min_samples_leaf': 4, 'max_features': 'sqrt', 'bootstrap': True}. Best is trial 0 with value: 0.016619358470890622.
# [I 2025-05-23 02:16:01,861] Trial 1 finished with value: 0.002236401389381393 and parameters: {'n_estimators': 100, 'max_depth': 20, 'min_samples_split': 7, 'min_samples_leaf': 3, 'max_features': 'sqrt', 'bootstrap': True}. Best is trial 0 with value: 0.016619358470890622.
# [I 2025-05-23 02:16:04,516] Trial 2 finished with value: -0.022864593880507343 and parameters: {'n_estimators': 200, 'max_depth': 15, 'min_samples_split': 5, 'min_samples_leaf': 3, 'max_features': 'sqrt', 'bootstrap': False}. Best is trial 0 with value: 0.016619358470890622.
# [I 2025-05-23 02:16:09,586] Trial 3 finished with value: -0.03483930813171558 and parameters: {'n_estimators': 400, 'max_depth': 30, 'min_samples_split': 5, 'min_samples_leaf': 1, 'max_features': 'log2', 'bootstrap': True}. Best is trial 0 with value: 0.016619358470890622.
# [I 2025-05-23 02:16:11,752] Trial 4 finished with value: 0.017673581935093143 and parameters: {'n_estimators': 200, 'max_depth': 5, 'min_samples_split': 2, 'min_samples_leaf': 3, 'max_features': 'log2', 'bootstrap': True}. Best is trial 4 with value: 0.017673581935093143.
# [I 2025-05-23 02:16:16,132] Trial 5 finished with value: -0.048148942064900925 and parameters: {'n_estimators': 400, 'max_depth': 25, 'min_samples_split': 2, 'min_samples_leaf': 2, 'max_features': 'sqrt', 'bootstrap': False}. Best is trial 4 with value: 0.017673581935093143.
# [I 2025-05-23 02:16:19,153] Trial 6 finished with value: 0.005392352300177983 and parameters: {'n_estimators': 300, 'max_depth': 30, 'min_samples_split': 3, 'min_samples_leaf': 3, 'max_features': 'log2', 'bootstrap': True}. Best is trial 4 with value: 0.017673581935093143.
# [I 2025-05-23 02:16:23,682] Trial 7 finished with value: 0.011514198688089894 and parameters: {'n_estimators': 800, 'max_depth': 5, 'min_samples_split': 10, 'min_samples_leaf': 2, 'max_features': 'sqrt', 'bootstrap': False}. Best is trial 4 with value: 0.017673581935093143.
# [I 2025-05-23 02:16:25,841] Trial 8 finished with value: 0.017945325733354965 and parameters: {'n_estimators': 200, 'max_depth': 15, 'min_samples_split': 10, 'min_samples_leaf': 3, 'max_features': 'log2', 'bootstrap': True}. Best is trial 8 with value: 0.017945325733354965.
# [I 2025-05-23 02:16:31,635] Trial 9 finished with value: -0.03696828535797754 and parameters: {'n_estimators': 600, 'max_depth': 15, 'min_samples_split': 2, 'min_samples_leaf': 1, 'max_features': 'log2', 'bootstrap': True}. Best is trial 8 with value: 0.017945325733354965.
# [I 2025-05-23 02:16:48,504] Trial 10 finished with value: -0.29817405934831887 and parameters: {'n_estimators': 1000, 'max_depth': 10, 'min_samples_split': 8, 'min_samples_leaf': 5, 'max_features': None, 'bootstrap': False}. Best is trial 8 with value: 0.017945325733354965.
# [I 2025-05-23 02:16:49,408] Trial 11 finished with value: 0.018715599720300458 and parameters: {'n_estimators': 100, 'max_depth': 5, 'min_samples_split': 4, 'min_samples_leaf': 4, 'max_features': 'log2', 'bootstrap': True}. Best is trial 11 with value: 0.018715599720300458.
# [I 2025-05-23 02:16:50,407] Trial 12 finished with value: 0.01550491252378976 and parameters: {'n_estimators': 100, 'max_depth': 10, 'min_samples_split': 4, 'min_samples_leaf': 5, 'max_features': 'log2', 'bootstrap': True}. Best is trial 11 with value: 0.018715599720300458.
# [I 2025-05-23 02:16:58,119] Trial 13 finished with value: -0.005283888256959246 and parameters: {'n_estimators': 400, 'max_depth': 10, 'min_samples_split': 6, 'min_samples_leaf': 4, 'max_features': None, 'bootstrap': True}. Best is trial 11 with value: 0.018715599720300458.
# [I 2025-05-23 02:16:59,228] Trial 14 finished with value: 0.01004927336388084 and parameters: {'n_estimators': 100, 'max_depth': 20, 'min_samples_split': 10, 'min_samples_leaf': 4, 'max_features': 'log2', 'bootstrap': True}. Best is trial 11 with value: 0.018715599720300458.
# [I 2025-05-23 02:17:01,867] Trial 15 finished with value: 0.018449552913286406 and parameters: {'n_estimators': 300, 'max_depth': 5, 'min_samples_split': 7, 'min_samples_leaf': 4, 'max_features': 'log2', 'bootstrap': True}. Best is trial 11 with value: 0.018715599720300458.
# [I 2025-05-23 02:17:05,202] Trial 16 finished with value: 0.021231820485993723 and parameters: {'n_estimators': 500, 'max_depth': 5, 'min_samples_split': 7, 'min_samples_leaf': 4, 'max_features': 'log2', 'bootstrap': True}. Best is trial 16 with value: 0.021231820485993723.
# [W 2025-05-23 02:17:13,827] Trial 17 failed with parameters: {'n_estimators': 900, 'max_depth': 5, 'min_samples_split': 4, 'min_samples_leaf': 5, 'max_features': None, 'bootstrap': True} because of the following error: KeyboardInterrupt().
# Traceback (most recent call last):
#   File "c:\Users\thoma\anaconda3\Lib\site-packages\optuna\study\_optimize.py", line 197, in _run_trial
#     value_or_values = func(trial)
#                       ^^^^^^^^^^^
#   File "C:\Users\thoma\AppData\Local\Temp\ipykernel_3244\3823881864.py", line 37, in objective
#     cv_scores = cross_val_score(
#                 ^^^^^^^^^^^^^^^^
#   File "c:\Users\thoma\anaconda3\Lib\site-packages\sklearn\model_selection\_validation.py", line 515, in cross_val_score
#     cv_results = cross_validate(
#                  ^^^^^^^^^^^^^^^
#   File "c:\Users\thoma\anaconda3\Lib\site-packages\sklearn\model_selection\_validation.py", line 266, in cross_validate
#     results = parallel(
#               ^^^^^^^^^
#   File "c:\Users\thoma\anaconda3\Lib\site-packages\sklearn\utils\parallel.py", line 63, in __call__
#     return super().__call__(iterable_with_config)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\thoma\anaconda3\Lib\site-packages\joblib\parallel.py", line 1088, in __call__
#     while self.dispatch_one_batch(iterator):
#           ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\thoma\anaconda3\Lib\site-packages\joblib\parallel.py", line 901, in dispatch_one_batch
#     self._dispatch(tasks)
#   File "c:\Users\thoma\anaconda3\Lib\site-packages\joblib\parallel.py", line 819, in _dispatch
#     job = self._backend.apply_async(batch, callback=cb)
#           ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\thoma\anaconda3\Lib\site-packages\joblib\_parallel_backends.py", line 208, in apply_async
#     result = ImmediateResult(func)
#              ^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\thoma\anaconda3\Lib\site-packages\joblib\_parallel_backends.py", line 597, in __init__
#     self.results = batch()
#                    ^^^^^^^
#   File "c:\Users\thoma\anaconda3\Lib\site-packages\joblib\parallel.py", line 288, in __call__
#     return [func(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\thoma\anaconda3\Lib\site-packages\joblib\parallel.py", line 288, in <listcomp>
#     return [func(*args, **kwargs)
#             ^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\thoma\anaconda3\Lib\site-packages\sklearn\utils\parallel.py", line 123, in __call__
#     return self.function(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\thoma\anaconda3\Lib\site-packages\sklearn\model_selection\_validation.py", line 686, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "c:\Users\thoma\anaconda3\Lib\site-packages\sklearn\ensemble\_forest.py", line 473, in fit
#     trees = Parallel(
#             ^^^^^^^^^
#   File "c:\Users\thoma\anaconda3\Lib\site-packages\sklearn\utils\parallel.py", line 63, in __call__
#     return super().__call__(iterable_with_config)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\thoma\anaconda3\Lib\site-packages\joblib\parallel.py", line 1098, in __call__
#     self.retrieve()
#   File "c:\Users\thoma\anaconda3\Lib\site-packages\joblib\parallel.py", line 975, in retrieve
#     self._output.extend(job.get(timeout=self.timeout))
#                         ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\thoma\anaconda3\Lib\site-packages\joblib\_parallel_backends.py", line 567, in wrap_future_result
#     return future.result(timeout=timeout)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\thoma\anaconda3\Lib\concurrent\futures\_base.py", line 451, in result
#     self._condition.wait(timeout)
#   File "c:\Users\thoma\anaconda3\Lib\threading.py", line 320, in wait
#     waiter.acquire()
# KeyboardInterrupt
# [W 2025-05-23 02:17:13,830] Trial 17 failed with value None.
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[24], line 51
#      48 study = optuna.create_study(direction='maximize')
#      50 # Run the optimization with 100 trials
# ---> 51 study.optimize(objective, n_trials=100)
#      53 # Print the best parameters and score
#      54 print("Best parameters:", study.best_params)
#
# File c:\Users\thoma\anaconda3\Lib\site-packages\optuna\study\study.py:475, in Study.optimize(self, func, n_trials, timeout, n_jobs, catch, callbacks, gc_after_trial, show_progress_bar)
#     373 def optimize(
#     374     self,
#     375     func: ObjectiveFuncType,
#    (...)
#     382     show_progress_bar: bool = False,
#     383 ) -> None:
#     384     """Optimize an objective function.
#     385
#     386     Optimization is done by choosing a suitable set of hyperparameter values from a given
#    (...)
#     473             If nested invocation of this method occurs.
#     474     """
# --> 475     _optimize(
#     476         study=self,
#     477         func=func,
#     478         n_trials=n_trials,
#     479         timeout=timeout,
#     480         n_jobs=n_jobs,
#     481         catch=tuple(catch) if isinstance(catch, Iterable) else (catch,),
#     482         callbacks=callbacks,
#     483         gc_after_trial=gc_after_trial,
#     484         show_progress_bar=show_progress_bar,
#     485     )
#
# File c:\Users\thoma\anaconda3\Lib\site-packages\optuna\study\_optimize.py:63, in _optimize(study, func, n_trials, timeout, n_jobs, catch, callbacks, gc_after_trial, show_progress_bar)
#      61 try:
#      62     if n_jobs == 1:
# ---> 63         _optimize_sequential(
#      64             study,
#      65             func,
#      66             n_trials,
#      67             timeout,
#      68             catch,
#      69             callbacks,
#      70             gc_after_trial,
#      71             reseed_sampler_rng=False,
#      72             time_start=None,
#      73             progress_bar=progress_bar,
#      74         )
#      75     else:
#      76         if n_jobs == -1:
#
# File c:\Users\thoma\anaconda3\Lib\site-packages\optuna\study\_optimize.py:160, in _optimize_sequential(study, func, n_trials, timeout, catch, callbacks, gc_after_trial, reseed_sampler_rng, time_start, progress_bar)
#     157         break
#     159 try:
# --> 160     frozen_trial = _run_trial(study, func, catch)
#     161 finally:
#     162     # The following line mitigates memory problems that can be occurred in some
#     163     # environments (e.g., services that use computing containers such as GitHub Actions).
#     164     # Please refer to the following PR for further details:
#     165     # https://github.com/optuna/optuna/pull/325.
#     166     if gc_after_trial:
#
# File c:\Users\thoma\anaconda3\Lib\site-packages\optuna\study\_optimize.py:248, in _run_trial(study, func, catch)
#     241         assert False, "Should not reach."
#     243 if (
#     244     frozen_trial.state == TrialState.FAIL
#     245     and func_err is not None
#     246     and not isinstance(func_err, catch)
#     247 ):
# --> 248     raise func_err
#     249 return frozen_trial
#
# File c:\Users\thoma\anaconda3\Lib\site-packages\optuna\study\_optimize.py:197, in _run_trial(study, func, catch)
#     195 with get_heartbeat_thread(trial._trial_id, study._storage):
#     196     try:
# --> 197         value_or_values = func(trial)
#     198     except exceptions.TrialPruned as e:
#     199         # TODO(mamu): Handle multi-objective cases.
#     200         state = TrialState.PRUNED
#
# Cell In[24], line 37, in objective(trial)
#      34 kf = KFold(n_splits=5, shuffle=True, random_state=42)
#      36 # Calculate the cross-validation score using Spearman correlation
# ---> 37 cv_scores = cross_val_score(
#      38     rf_model,
#      39     X_train_features,
#      40     y_train,
#      41     cv=kf,
#      42 )
#      44 # Return the mean score to maximize
#      45 return cv_scores.mean()
#
# File c:\Users\thoma\anaconda3\Lib\site-packages\sklearn\model_selection\_validation.py:515, in cross_val_score(estimator, X, y, groups, scoring, cv, n_jobs, verbose, fit_params, pre_dispatch, error_score)
#     512 # To ensure multimetric format is not supported
#     513 scorer = check_scoring(estimator, scoring=scoring)
# --> 515 cv_results = cross_validate(
#     516     estimator=estimator,
#     517     X=X,
#     518     y=y,
#     519     groups=groups,
#     520     scoring={"score": scorer},
#     521     cv=cv,
#     522     n_jobs=n_jobs,
#     523     verbose=verbose,
#     524     fit_params=fit_params,
#     525     pre_dispatch=pre_dispatch,
#     526     error_score=error_score,
#     527 )
#     528 return cv_results["test_score"]
#
# File c:\Users\thoma\anaconda3\Lib\site-packages\sklearn\model_selection\_validation.py:266, in cross_validate(estimator, X, y, groups, scoring, cv, n_jobs, verbose, fit_params, pre_dispatch, return_train_score, return_estimator, error_score)
#     263 # We clone the estimator to make sure that all the folds are
#     264 # independent, and that it is pickle-able.
#     265 parallel = Parallel(n_jobs=n_jobs, verbose=verbose, pre_dispatch=pre_dispatch)
# --> 266 results = parallel(
#     267     delayed(_fit_and_score)(
#     268         clone(estimator),
#     269         X,
#     270         y,
#     271         scorers,
#     272         train,
#     273         test,
#     274         verbose,
#     275         None,
#     276         fit_params,
#     277         return_train_score=return_train_score,
#     278         return_times=True,
#     279         return_estimator=return_estimator,
#     280         error_score=error_score,
#     281     )
#     282     for train, test in cv.split(X, y, groups)
#     283 )
#     285 _warn_or_raise_about_fit_failures(results, error_score)
#     287 # For callabe scoring, the return type is only know after calling. If the
#     288 # return type is a dictionary, the error scores can now be inserted with
#     289 # the correct key.
#
# File c:\Users\thoma\anaconda3\Lib\site-packages\sklearn\utils\parallel.py:63, in Parallel.__call__(self, iterable)
#      58 config = get_config()
#      59 iterable_with_config = (
#      60     (_with_config(delayed_func, config), args, kwargs)
#      61     for delayed_func, args, kwargs in iterable
#      62 )
# ---> 63 return super().__call__(iterable_with_config)
#
# File c:\Users\thoma\anaconda3\Lib\site-packages\joblib\parallel.py:1088, in Parallel.__call__(self, iterable)
#    1085 if self.dispatch_one_batch(iterator):
#    1086     self._iterating = self._original_iterator is not None
# -> 1088 while self.dispatch_one_batch(iterator):
#    1089     pass
#    1091 if pre_dispatch == "all" or n_jobs == 1:
#    1092     # The iterable was consumed all at once by the above for loop.
#    1093     # No need to wait for async callbacks to trigger to
#    1094     # consumption.
#
# File c:\Users\thoma\anaconda3\Lib\site-packages\joblib\parallel.py:901, in Parallel.dispatch_one_batch(self, iterator)
#     899     return False
#     900 else:
# --> 901     self._dispatch(tasks)
#     902     return True
#
# File c:\Users\thoma\anaconda3\Lib\site-packages\joblib\parallel.py:819, in Parallel._dispatch(self, batch)
#     817 with self._lock:
#     818     job_idx = len(self._jobs)
# --> 819     job = self._backend.apply_async(batch, callback=cb)
#     820     # A job can complete so quickly than its callback is
#     821     # called before we get here, causing self._jobs to
#     822     # grow. To ensure correct results ordering, .insert is
#     823     # used (rather than .append) in the following line
#     824     self._jobs.insert(job_idx, job)
#
# File c:\Users\thoma\anaconda3\Lib\site-packages\joblib\_parallel_backends.py:208, in SequentialBackend.apply_async(self, func, callback)
#     206 def apply_async(self, func, callback=None):
#     207     """Schedule a func to be run"""
# --> 208     result = ImmediateResult(func)
#     209     if callback:
#     210         callback(result)
#
# File c:\Users\thoma\anaconda3\Lib\site-packages\joblib\_parallel_backends.py:597, in ImmediateResult.__init__(self, batch)
#     594 def __init__(self, batch):
#     595     # Don't delay the application, to avoid keeping the input
#     596     # arguments in memory
# --> 597     self.results = batch()
#
# File c:\Users\thoma\anaconda3\Lib\site-packages\joblib\parallel.py:288, in BatchedCalls.__call__(self)
#     284 def __call__(self):
#     285     # Set the default nested backend to self._backend but do not set the
#     286     # change the default number of processes to -1
#     287     with parallel_backend(self._backend, n_jobs=self._n_jobs):
# --> 288         return [func(*args, **kwargs)
#     289                 for func, args, kwargs in self.items]
#
# File c:\Users\thoma\anaconda3\Lib\site-packages\joblib\parallel.py:288, in <listcomp>(.0)
#     284 def __call__(self):
#     285     # Set the default nested backend to self._backend but do not set the
#     286     # change the default number of processes to -1
#     287     with parallel_backend(self._backend, n_jobs=self._n_jobs):
# --> 288         return [func(*args, **kwargs)
#     289                 for func, args, kwargs in self.items]
#
# File c:\Users\thoma\anaconda3\Lib\site-packages\sklearn\utils\parallel.py:123, in _FuncWrapper.__call__(self, *args, **kwargs)
#     121     config = {}
#     122 with config_context(**config):
# --> 123     return self.function(*args, **kwargs)
#
# File c:\Users\thoma\anaconda3\Lib\site-packages\sklearn\model_selection\_validation.py:686, in _fit_and_score(estimator, X, y, scorer, train, test, verbose, parameters, fit_params, return_train_score, return_parameters, return_n_test_samples, return_times, return_estimator, split_progress, candidate_progress, error_score)
#     684         estimator.fit(X_train, **fit_params)
#     685     else:
# --> 686         estimator.fit(X_train, y_train, **fit_params)
#     688 except Exception:
#     689     # Note fit time as time until error
#     690     fit_time = time.time() - start_time
#
# File c:\Users\thoma\anaconda3\Lib\site-packages\sklearn\ensemble\_forest.py:473, in BaseForest.fit(self, X, y, sample_weight)
#     462 trees = [
#     463     self._make_estimator(append=False, random_state=random_state)
#     464     for i in range(n_more_estimators)
#     465 ]
#     467 # Parallel loop: we prefer the threading backend as the Cython code
#     468 # for fitting the trees is internally releasing the Python GIL
#     469 # making threading more efficient than multiprocessing in
#     470 # that case. However, for joblib 0.12+ we respect any
#     471 # parallel_backend contexts set at a higher level,
#     472 # since correctness does not rely on using threads.
# --> 473 trees = Parallel(
#     474     n_jobs=self.n_jobs,
#     475     verbose=self.verbose,
#     476     prefer="threads",
#     477 )(
#     478     delayed(_parallel_build_trees)(
#     479         t,
#     480         self.bootstrap,
#     481         X,
#     482         y,
#     483         sample_weight,
#     484         i,
#     485         len(trees),
#     486         verbose=self.verbose,
#     487         class_weight=self.class_weight,
#     488         n_samples_bootstrap=n_samples_bootstrap,
#     489     )
#     490     for i, t in enumerate(trees)
#     491 )
#     493 # Collect newly grown trees
#     494 self.estimators_.extend(trees)
#
# File c:\Users\thoma\anaconda3\Lib\site-packages\sklearn\utils\parallel.py:63, in Parallel.__call__(self, iterable)
#      58 config = get_config()
#      59 iterable_with_config = (
#      60     (_with_config(delayed_func, config), args, kwargs)
#      61     for delayed_func, args, kwargs in iterable
#      62 )
# ---> 63 return super().__call__(iterable_with_config)
#
# File c:\Users\thoma\anaconda3\Lib\site-packages\joblib\parallel.py:1098, in Parallel.__call__(self, iterable)
#    1095     self._iterating = False
#    1097 with self._backend.retrieval_context():
# -> 1098     self.retrieve()
#    1099 # Make sure that we get a last message telling us we are done
#    1100 elapsed_time = time.time() - self._start_time
#
# File c:\Users\thoma\anaconda3\Lib\site-packages\joblib\parallel.py:975, in Parallel.retrieve(self)
#     973 try:
#     974     if getattr(self._backend, 'supports_timeout', False):
# --> 975         self._output.extend(job.get(timeout=self.timeout))
#     976     else:
#     977         self._output.extend(job.get())
#
# File c:\Users\thoma\anaconda3\Lib\site-packages\joblib\_parallel_backends.py:567, in LokyBackend.wrap_future_result(future, timeout)
#     564 """Wrapper for Future.result to implement the same behaviour as
#     565 AsyncResults.get from multiprocessing."""
#     566 try:
# --> 567     return future.result(timeout=timeout)
#     568 except CfTimeoutError as e:
#     569     raise TimeoutError from e
#
# File c:\Users\thoma\anaconda3\Lib\concurrent\futures\_base.py:451, in Future.result(self, timeout)
#     448 elif self._state == FINISHED:
#     449     return self.__get_result()
# --> 451 self._condition.wait(timeout)
#     453 if self._state in [CANCELLED, CANCELLED_AND_NOTIFIED]:
#     454     raise CancelledError()
#
# File c:\Users\thoma\anaconda3\Lib\threading.py:320, in Condition.wait(self, timeout)
#     318 try:    # restore state no matter what (e.g., KeyboardInterrupt)
#     319     if timeout is None:
# --> 320         waiter.acquire()
#     321         gotit = True
#     322     else:
#
# KeyboardInterrupt:

# %% [markdown]
# Catboost

# %%
# Define the objective function for Optuna
def objective(trial):
    # Define hyperparameters to optimize
    params = {
        'iterations': trial.suggest_int('iterations', 100, 1000, step=100),
        'learning_rate': trial.suggest_float('learning_rate', 0.001, 0.05, log=True),
        'depth': trial.suggest_int('depth', 4, 10),
        'l2_leaf_reg': trial.suggest_float('l2_leaf_reg', 1.0, 10.0),
        'subsample': trial.suggest_float('subsample', 0.6, 1.0),
        'random_strength': trial.suggest_float('random_strength', 1e-9, 10.0, log=True),
        'border_count': trial.suggest_int('border_count', 32, 255),
        'bagging_temperature': trial.suggest_float('bagging_temperature', 0.0, 1.0),
        'verbose': False,
        'random_seed': 42
    }
    
    # Create CatBoost model with the suggested parameters
    model = CatBoostRegressor(**params)
    
    # Perform cross-validation
    cv_scores = cross_val_score(
        model, 
        X_train_features, 
        y_train,
        cv=kf,
        scoring=spearman_scorer
    )
    
    # Return the mean CV score (higher is better)
    return cv_scores.mean()

# Create a study object and optimize the objective function
study = optuna.create_study(direction='maximize')
study.optimize(objective, n_trials=20)  # Adjust n_trials as needed

# Print the best parameters and score
print("Best trial:")
print(f"  Value (Spearman correlation): {study.best_trial.value:.4f}")
print("  Best parameters:")
for key, value in study.best_trial.params.items():
    print(f"    {key}: {value}")

# %% [markdown]
# LGBM

# %%
import optuna
from lightgbm import LGBMRegressor
from sklearn.model_selection import cross_val_score, KFold
from sklearn.model_selection import cross_val_score, KFold
from sklearn.metrics import make_scorer
from sklearn.metrics import mean_squared_error


# Define a scorer function using RMSE (Root Mean Squared Error)
def rmse_score(y_true, y_pred):
    """Calculate Root Mean Squared Error between predictions and actual values."""
    return -np.sqrt(mean_squared_error(y_true, y_pred))  # Negative because sklearn maximizes scores

# Create a scorer using RMSE (lower is better, but we negate since sklearn maximizes)
spearman_scorer = make_scorer(rmse_score)

kf = KFold(n_splits=5, shuffle=True, random_state=42)

def objective(trial):
    #
    params = {
        'objective': 'regression',
        'metric': 'rmse',  # We'll optimize RMSE, but evaluate with Spearman correlation
        'n_estimators': trial.suggest_int('n_estimators', 100, 500),
        'learning_rate': trial.suggest_float('learning_rate', 0.001, 0.05, log=True),
        'max_depth': trial.suggest_int('max_depth', 4, 12),
        'num_leaves': trial.suggest_int('num_leaves', 15, 100),
        'subsample': trial.suggest_float('subsample', 0.6, 1.0),
        'colsample_bytree': trial.suggest_float('colsample_bytree', 0.6, 1.0),
        'min_child_samples': trial.suggest_int('min_child_samples', 5, 30),
        'reg_alpha': trial.suggest_float('reg_alpha', 1e-8, 10.0, log=True),
        'reg_lambda': trial.suggest_float('reg_lambda', 1e-8, 10.0, log=True),
        'random_state': 42,
        'verbose': [-1]
    }
    
    # Create model with the specified parameters
    model = LGBMRegressor(**params)
    
    # Cross-validate the model
    cv_scores = cross_val_score(
        model, 
        X_train_features, 
        y_train,
        cv=kf,
        scoring=spearman_scorer
    )
    
    # Return the mean score (higher is better, so no negative sign needed)
    return cv_scores.mean()

# Create an Optuna study to maximize the score
study = optuna.create_study(direction='maximize')

# Run the optimization
study.optimize(objective, n_trials=200)

# Print the best parameters and score
print("Best trial:")
print(f"  Value (Spearman correlation): {study.best_trial.value:.4f}")
print("  Params:")
for key, value in study.best_trial.params.items():
    print(f"    {key}: {value}")

# Train a final model with the best parameters
best_params = study.best_trial.params
best_lgbm = LGBMRegressor(**best_params)

# Perform cross-validation again with the best model to verify performance
best_cv_scores = cross_val_score(
    best_lgbm, 
    X_train_features, 
    y_train,
    cv=kf,
    scoring=spearman_scorer
)

print(f"\nCross-validation scores with best model: {best_cv_scores}")
print(f"Mean score: {best_cv_scores.mean():.4f}")
print(f"Standard deviation: {best_cv_scores.std():.4f}")
# Out:
# [I 2025-05-23 01:55:43,216] A new study created in memory with name: no-name-64c21fd6-713b-4527-894c-f1c82b9629bf
# [I 2025-05-23 01:55:44,448] Trial 0 finished with value: -1.024739113293998 and parameters: {'n_estimators': 254, 'learning_rate': 0.001283904652594155, 'max_depth': 12, 'num_leaves': 34, 'subsample': 0.951083385711849, 'colsample_bytree': 0.6706988438864443, 'min_child_samples': 19, 'reg_alpha': 4.362271176476796e-05, 'reg_lambda': 1.6872443361631832e-05}. Best is trial 0 with value: -1.024739113293998.
# [I 2025-05-23 01:55:44,686] Trial 1 finished with value: -1.0262373469833461 and parameters: {'n_estimators': 106, 'learning_rate': 0.0034722846956951776, 'max_depth': 4, 'num_leaves': 23, 'subsample': 0.6722421860616014, 'colsample_bytree': 0.7112993121833943, 'min_child_samples': 7, 'reg_alpha': 1.3361951528465243e-07, 'reg_lambda': 0.000238961169545351}. Best is trial 0 with value: -1.024739113293998.
# [I 2025-05-23 01:55:47,118] Trial 2 finished with value: -1.02934492365818 and parameters: {'n_estimators': 270, 'learning_rate': 0.0015552778195212962, 'max_depth': 12, 'num_leaves': 69, 'subsample': 0.6784423141598208, 'colsample_bytree': 0.9954177432379745, 'min_child_samples': 11, 'reg_alpha': 0.015216801270584487, 'reg_lambda': 2.72341609831856e-07}. Best is trial 0 with value: -1.024739113293998.
# [I 2025-05-23 01:55:49,986] Trial 3 finished with value: -1.0729701092035882 and parameters: {'n_estimators': 477, 'learning_rate': 0.009712832459204445, 'max_depth': 8, 'num_leaves': 86, 'subsample': 0.8493700026251159, 'colsample_bytree': 0.6637970783600967, 'min_child_samples': 5, 'reg_alpha': 5.677345730152187e-07, 'reg_lambda': 0.00015424805590801656}. Best is trial 0 with value: -1.024739113293998.
# [I 2025-05-23 01:55:51,025] Trial 4 finished with value: -1.094164919473577 and parameters: {'n_estimators': 305, 'learning_rate': 0.03655132622177755, 'max_depth': 8, 'num_leaves': 36, 'subsample': 0.9758982837995629, 'colsample_bytree': 0.6212396616408801, 'min_child_samples': 16, 'reg_alpha': 0.0001756523536575561, 'reg_lambda': 0.01898360945885778}. Best is trial 0 with value: -1.024739113293998.
# [I 2025-05-23 01:55:53,026] Trial 5 finished with value: -1.0329468292133537 and parameters: {'n_estimators': 189, 'learning_rate': 0.006847136044567875, 'max_depth': 12, 'num_leaves': 94, 'subsample': 0.8094647807307738, 'colsample_bytree': 0.7542834216341439, 'min_child_samples': 10, 'reg_alpha': 0.010305298733221915, 'reg_lambda': 0.030569568380907523}. Best is trial 0 with value: -1.024739113293998.
# [I 2025-05-23 01:55:53,665] Trial 6 finished with value: -1.0244551577640997 and parameters: {'n_estimators': 199, 'learning_rate': 0.009022396818747965, 'max_depth': 7, 'num_leaves': 18, 'subsample': 0.6685299924735868, 'colsample_bytree': 0.6698748241562668, 'min_child_samples': 21, 'reg_alpha': 1.1691501408421987e-06, 'reg_lambda': 0.00014661356696115828}. Best is trial 6 with value: -1.0244551577640997.
# [I 2025-05-23 01:55:55,562] Trial 7 finished with value: -1.0503069031518186 and parameters: {'n_estimators': 410, 'learning_rate': 0.01938761090926379, 'max_depth': 11, 'num_leaves': 77, 'subsample': 0.8870031592027251, 'colsample_bytree': 0.6299363506681906, 'min_child_samples': 28, 'reg_alpha': 4.654926692314547, 'reg_lambda': 0.1540358998800614}. Best is trial 6 with value: -1.0244551577640997.
# [I 2025-05-23 01:55:56,252] Trial 8 finished with value: -1.0223421261727215 and parameters: {'n_estimators': 185, 'learning_rate': 0.003201052304045803, 'max_depth': 6, 'num_leaves': 56, 'subsample': 0.9554412994655926, 'colsample_bytree': 0.6819066773120028, 'min_child_samples': 29, 'reg_alpha': 0.0010994547903076747, 'reg_lambda': 1.1039499069764297e-05}. Best is trial 8 with value: -1.0223421261727215.
# [I 2025-05-23 01:55:59,978] Trial 9 finished with value: -1.1240705720405075 and parameters: {'n_estimators': 475, 'learning_rate': 0.02417787144722546, 'max_depth': 12, 'num_leaves': 100, 'subsample': 0.6455507288686454, 'colsample_bytree': 0.7858394114160621, 'min_child_samples': 9, 'reg_alpha': 2.5622134875432815e-06, 'reg_lambda': 0.0018043326610679877}. Best is trial 8 with value: -1.0223421261727215.
# [I 2025-05-23 01:56:00,407] Trial 10 finished with value: -1.0262422262835937 and parameters: {'n_estimators': 102, 'learning_rate': 0.0032468888248918886, 'max_depth': 5, 'num_leaves': 61, 'subsample': 0.7448533374388319, 'colsample_bytree': 0.8757562288522022, 'min_child_samples': 30, 'reg_alpha': 0.028152222270444425, 'reg_lambda': 5.095725764045132}. Best is trial 8 with value: -1.0223421261727215.
# [I 2025-05-23 01:56:01,190] Trial 11 finished with value: -1.0227693140865506 and parameters: {'n_estimators': 195, 'learning_rate': 0.0076510406470636, 'max_depth': 6, 'num_leaves': 48, 'subsample': 0.7485142038804167, 'colsample_bytree': 0.8552286932663248, 'min_child_samples': 24, 'reg_alpha': 1.5267323116236155e-08, 'reg_lambda': 6.642243358372487e-07}. Best is trial 8 with value: -1.0223421261727215.
# [I 2025-05-23 01:56:01,960] Trial 12 finished with value: -1.0211940893703821 and parameters: {'n_estimators': 186, 'learning_rate': 0.003935171158176644, 'max_depth': 6, 'num_leaves': 45, 'subsample': 0.7568725361951889, 'colsample_bytree': 0.8680971768694704, 'min_child_samples': 25, 'reg_alpha': 0.0008948898383881212, 'reg_lambda': 3.878561147409745e-08}. Best is trial 12 with value: -1.0211940893703821.
# [I 2025-05-23 01:56:02,997] Trial 13 finished with value: -1.0210754952731314 and parameters: {'n_estimators': 341, 'learning_rate': 0.0029437643377861924, 'max_depth': 6, 'num_leaves': 49, 'subsample': 0.9050082941909307, 'colsample_bytree': 0.8781629167933459, 'min_child_samples': 26, 'reg_alpha': 0.0013290370788586624, 'reg_lambda': 1.4273110149478728e-08}. Best is trial 13 with value: -1.0210754952731314.
# [I 2025-05-23 01:56:04,860] Trial 14 finished with value: -1.0224881213836583 and parameters: {'n_estimators': 343, 'learning_rate': 0.0021817147550322906, 'max_depth': 10, 'num_leaves': 45, 'subsample': 0.8925881570002802, 'colsample_bytree': 0.9304155500185205, 'min_child_samples': 25, 'reg_alpha': 0.5844803235456226, 'reg_lambda': 2.7213145264655633e-08}. Best is trial 13 with value: -1.0210754952731314.
# [I 2025-05-23 01:56:05,541] Trial 15 finished with value: -1.0200150203557456 and parameters: {'n_estimators': 363, 'learning_rate': 0.004958135881147892, 'max_depth': 4, 'num_leaves': 33, 'subsample': 0.7468912121091139, 'colsample_bytree': 0.8560262913171087, 'min_child_samples': 25, 'reg_alpha': 2.2235832300877588e-05, 'reg_lambda': 2.1572304820307606e-08}. Best is trial 15 with value: -1.0200150203557456.
# [I 2025-05-23 01:56:06,371] Trial 16 finished with value: -1.024956546217172 and parameters: {'n_estimators': 383, 'learning_rate': 0.0050930343278843895, 'max_depth': 4, 'num_leaves': 32, 'subsample': 0.8143431398643429, 'colsample_bytree': 0.9249946128515831, 'min_child_samples': 15, 'reg_alpha': 1.66315527792423e-05, 'reg_lambda': 7.803425387740815e-07}. Best is trial 15 with value: -1.0200150203557456.
# [I 2025-05-23 01:56:07,564] Trial 17 finished with value: -1.0234530644714956 and parameters: {'n_estimators': 423, 'learning_rate': 0.0019771033271454687, 'max_depth': 5, 'num_leaves': 56, 'subsample': 0.9082686608141771, 'colsample_bytree': 0.823445240659597, 'min_child_samples': 22, 'reg_alpha': 1.2215438369334245e-05, 'reg_lambda': 2.6992811099206598e-08}. Best is trial 15 with value: -1.0200150203557456.
# [I 2025-05-23 01:56:09,260] Trial 18 finished with value: -1.0248260243440224 and parameters: {'n_estimators': 338, 'learning_rate': 0.0010054254551568119, 'max_depth': 9, 'num_leaves': 27, 'subsample': 0.7151836418532013, 'colsample_bytree': 0.9348861484471988, 'min_child_samples': 26, 'reg_alpha': 0.00015587517648509036, 'reg_lambda': 5.842951822289165e-06}. Best is trial 15 with value: -1.0200150203557456.
# [I 2025-05-23 01:56:10,111] Trial 19 finished with value: -1.0368177719349208 and parameters: {'n_estimators': 361, 'learning_rate': 0.013140968910192303, 'max_depth': 5, 'num_leaves': 15, 'subsample': 0.6090501339808134, 'colsample_bytree': 0.8077865720014694, 'min_child_samples': 21, 'reg_alpha': 0.08624387115677164, 'reg_lambda': 1.0446302045832081e-08}. Best is trial 15 with value: -1.0200150203557456.
# [I 2025-05-23 01:56:12,127] Trial 20 finished with value: -1.0335128829389943 and parameters: {'n_estimators': 443, 'learning_rate': 0.00579009181452509, 'max_depth': 7, 'num_leaves': 40, 'subsample': 0.8540769563888251, 'colsample_bytree': 0.9911072220940745, 'min_child_samples': 18, 'reg_alpha': 0.0018487701491712138, 'reg_lambda': 1.7975204837366975e-07}. Best is trial 15 with value: -1.0200150203557456.
# [I 2025-05-23 01:56:13,133] Trial 21 finished with value: -1.0223180184854308 and parameters: {'n_estimators': 306, 'learning_rate': 0.004191171001159629, 'max_depth': 6, 'num_leaves': 46, 'subsample': 0.7670032058221609, 'colsample_bytree': 0.8785028123872205, 'min_child_samples': 27, 'reg_alpha': 0.0013921275652844201, 'reg_lambda': 6.516554313791888e-08}. Best is trial 15 with value: -1.0200150203557456.
# [I 2025-05-23 01:56:13,817] Trial 22 finished with value: -1.0232532654273199 and parameters: {'n_estimators': 261, 'learning_rate': 0.002512003557047932, 'max_depth': 4, 'num_leaves': 51, 'subsample': 0.7813885311939585, 'colsample_bytree': 0.8530682394259131, 'min_child_samples': 23, 'reg_alpha': 0.0004151980206664303, 'reg_lambda': 1.0097736774920143e-08}. Best is trial 15 with value: -1.0200150203557456.
# [I 2025-05-23 01:56:15,571] Trial 23 finished with value: -1.0238548678753847 and parameters: {'n_estimators': 383, 'learning_rate': 0.004639358630455906, 'max_depth': 7, 'num_leaves': 65, 'subsample': 0.7074241351870483, 'colsample_bytree': 0.9008808760564067, 'min_child_samples': 26, 'reg_alpha': 6.117542845339862e-05, 'reg_lambda': 2.168148292302496e-06}. Best is trial 15 with value: -1.0200150203557456.
# [I 2025-05-23 01:56:16,091] Trial 24 finished with value: -1.0259898769511708 and parameters: {'n_estimators': 140, 'learning_rate': 0.0023596520420212873, 'max_depth': 5, 'num_leaves': 41, 'subsample': 0.8213673271053226, 'colsample_bytree': 0.8324372620183627, 'min_child_samples': 24, 'reg_alpha': 8.004256330452678e-06, 'reg_lambda': 1.538083172812378e-07}. Best is trial 15 with value: -1.0200150203557456.
# [I 2025-05-23 01:56:16,983] Trial 25 finished with value: -1.0337407675748669 and parameters: {'n_estimators': 222, 'learning_rate': 0.013196549695173396, 'max_depth': 6, 'num_leaves': 26, 'subsample': 0.7241615222210019, 'colsample_bytree': 0.7824779321304178, 'min_child_samples': 13, 'reg_alpha': 0.004579807168292823, 'reg_lambda': 1.1724439290960266e-06}. Best is trial 15 with value: -1.0200150203557456.
# [I 2025-05-23 01:56:19,406] Trial 26 finished with value: -1.0260048318004096 and parameters: {'n_estimators': 321, 'learning_rate': 0.003947649218096704, 'max_depth': 9, 'num_leaves': 41, 'subsample': 0.7876829631882647, 'colsample_bytree': 0.9539504096539085, 'min_child_samples': 20, 'reg_alpha': 0.19914764051021105, 'reg_lambda': 6.644519443626625e-08}. Best is trial 15 with value: -1.0200150203557456.
# [I 2025-05-23 01:56:20,355] Trial 27 finished with value: -1.021034082117442 and parameters: {'n_estimators': 380, 'learning_rate': 0.0027604193509963527, 'max_depth': 4, 'num_leaves': 51, 'subsample': 0.85621939240602, 'colsample_bytree': 0.7504586496211574, 'min_child_samples': 28, 'reg_alpha': 0.00040636889782771495, 'reg_lambda': 3.6153692992537464e-05}. Best is trial 15 with value: -1.0200150203557456.
# [I 2025-05-23 01:56:21,476] Trial 28 finished with value: -1.022797492008213 and parameters: {'n_estimators': 377, 'learning_rate': 0.0015183105574114466, 'max_depth': 4, 'num_leaves': 73, 'subsample': 0.9289080916991428, 'colsample_bytree': 0.7385805849207725, 'min_child_samples': 30, 'reg_alpha': 6.804837668241754e-05, 'reg_lambda': 0.002315794833153877}. Best is trial 15 with value: -1.0200150203557456.
# [I 2025-05-23 01:56:22,656] Trial 29 finished with value: -1.0220644271806485 and parameters: {'n_estimators': 279, 'learning_rate': 0.0028042235218216117, 'max_depth': 5, 'num_leaves': 32, 'subsample': 0.8578371998415621, 'colsample_bytree': 0.7592998978616401, 'min_child_samples': 28, 'reg_alpha': 2.286308787129291e-07, 'reg_lambda': 2.5835638368087492e-05}. Best is trial 15 with value: -1.0200150203557456.
# [I 2025-05-23 01:56:23,652] Trial 30 finished with value: -1.0231660970426293 and parameters: {'n_estimators': 417, 'learning_rate': 0.0017665254513219723, 'max_depth': 4, 'num_leaves': 53, 'subsample': 0.9311842849322369, 'colsample_bytree': 0.7191214334800143, 'min_child_samples': 19, 'reg_alpha': 5.280193746602998e-06, 'reg_lambda': 4.882053149436042e-05}. Best is trial 15 with value: -1.0200150203557456.
# [I 2025-05-23 01:56:25,300] Trial 31 finished with value: -1.024843920185516 and parameters: {'n_estimators': 354, 'learning_rate': 0.005846656914583296, 'max_depth': 7, 'num_leaves': 61, 'subsample': 0.8387878092302475, 'colsample_bytree': 0.8947324329100689, 'min_child_samples': 26, 'reg_alpha': 0.0007998289537837341, 'reg_lambda': 3.1062541150096108e-06}. Best is trial 15 with value: -1.0200150203557456.
# [I 2025-05-23 01:56:25,855] Trial 32 finished with value: -1.0224477076949252 and parameters: {'n_estimators': 241, 'learning_rate': 0.0038829628213802128, 'max_depth': 4, 'num_leaves': 36, 'subsample': 0.9994580286714431, 'colsample_bytree': 0.8476056567021077, 'min_child_samples': 24, 'reg_alpha': 0.004151802651696591, 'reg_lambda': 4.568139962384551e-08}. Best is trial 15 with value: -1.0200150203557456.
# [I 2025-05-23 01:56:26,643] Trial 33 finished with value: -1.0252563811841438 and parameters: {'n_estimators': 287, 'learning_rate': 0.0012051386963749724, 'max_depth': 5, 'num_leaves': 49, 'subsample': 0.8792952132187825, 'colsample_bytree': 0.8087569034623893, 'min_child_samples': 28, 'reg_alpha': 0.00025572636655145153, 'reg_lambda': 2.888818301779025e-07}. Best is trial 15 with value: -1.0200150203557456.
# [I 2025-05-23 01:56:27,263] Trial 34 finished with value: -1.0247680910621888 and parameters: {'n_estimators': 147, 'learning_rate': 0.0029594355860347523, 'max_depth': 6, 'num_leaves': 44, 'subsample': 0.7650052964596266, 'colsample_bytree': 0.8737279770250639, 'min_child_samples': 22, 'reg_alpha': 4.780551140026955e-05, 'reg_lambda': 1.2800825266377044e-08}. Best is trial 15 with value: -1.0200150203557456.
# [I 2025-05-23 01:56:28,128] Trial 35 finished with value: -1.020292458086492 and parameters: {'n_estimators': 318, 'learning_rate': 0.005223914864680684, 'max_depth': 4, 'num_leaves': 22, 'subsample': 0.6928763194198764, 'colsample_bytree': 0.7810795223180943, 'min_child_samples': 27, 'reg_alpha': 0.03817427401142834, 'reg_lambda': 1.331630526381478e-07}. Best is trial 15 with value: -1.0200150203557456.
# [I 2025-05-23 01:56:28,869] Trial 36 finished with value: -1.0205240402542908 and parameters: {'n_estimators': 318, 'learning_rate': 0.007056350220270042, 'max_depth': 4, 'num_leaves': 24, 'subsample': 0.7024148979861697, 'colsample_bytree': 0.7639077688061523, 'min_child_samples': 30, 'reg_alpha': 0.03139183652922793, 'reg_lambda': 3.556423100430561e-07}. Best is trial 15 with value: -1.0200150203557456.
# [I 2025-05-23 01:56:29,577] Trial 37 finished with value: -1.0233201544872197 and parameters: {'n_estimators': 318, 'learning_rate': 0.011019736130418725, 'max_depth': 4, 'num_leaves': 22, 'subsample': 0.6904943149392544, 'colsample_bytree': 0.7166347049691939, 'min_child_samples': 30, 'reg_alpha': 1.6748511003355961, 'reg_lambda': 0.0009651535660444463}. Best is trial 15 with value: -1.0200150203557456.
# [I 2025-05-23 01:56:30,510] Trial 38 finished with value: -1.0223246269751187 and parameters: {'n_estimators': 448, 'learning_rate': 0.00716742592619752, 'max_depth': 4, 'num_leaves': 21, 'subsample': 0.6456705655745602, 'colsample_bytree': 0.766490400957369, 'min_child_samples': 28, 'reg_alpha': 0.03521668881748323, 'reg_lambda': 2.6315570904822585e-07}. Best is trial 15 with value: -1.0200150203557456.
# [I 2025-05-23 01:56:31,445] Trial 39 finished with value: -1.0271199082601818 and parameters: {'n_estimators': 393, 'learning_rate': 0.008701127263778585, 'max_depth': 5, 'num_leaves': 26, 'subsample': 0.6660129677859397, 'colsample_bytree': 0.6916006075883763, 'min_child_samples': 29, 'reg_alpha': 0.18617482934367244, 'reg_lambda': 5.536723019043081e-05}. Best is trial 15 with value: -1.0200150203557456.
# [I 2025-05-23 01:56:32,035] Trial 40 finished with value: -1.0199432770371455 and parameters: {'n_estimators': 292, 'learning_rate': 0.006084838930264736, 'max_depth': 4, 'num_leaves': 30, 'subsample': 0.7344570093251968, 'colsample_bytree': 0.7426351523220497, 'min_child_samples': 27, 'reg_alpha': 0.008016687914082629, 'reg_lambda': 6.4436249619541935e-06}. Best is trial 40 with value: -1.0199432770371455.
# [I 2025-05-23 01:56:32,629] Trial 41 finished with value: -1.019281788849477 and parameters: {'n_estimators': 291, 'learning_rate': 0.005557667935274217, 'max_depth': 4, 'num_leaves': 28, 'subsample': 0.7309331102090619, 'colsample_bytree': 0.7341385927100038, 'min_child_samples': 27, 'reg_alpha': 0.017038154769155118, 'reg_lambda': 6.278839417006355e-06}. Best is trial 41 with value: -1.019281788849477.
# [I 2025-05-23 01:56:33,242] Trial 42 finished with value: -1.0205876504049352 and parameters: {'n_estimators': 290, 'learning_rate': 0.00651097587305419, 'max_depth': 4, 'num_leaves': 29, 'subsample': 0.7349182579152244, 'colsample_bytree': 0.734120579342004, 'min_child_samples': 27, 'reg_alpha': 0.011103316240367584, 'reg_lambda': 3.46438468787e-06}. Best is trial 41 with value: -1.019281788849477.
# [I 2025-05-23 01:56:34,120] Trial 43 finished with value: -1.021105557351239 and parameters: {'n_estimators': 317, 'learning_rate': 0.005049095882586634, 'max_depth': 5, 'num_leaves': 18, 'subsample': 0.6958172364702011, 'colsample_bytree': 0.6504386453963346, 'min_child_samples': 29, 'reg_alpha': 0.023399927735086704, 'reg_lambda': 5.303710470478356e-07}. Best is trial 41 with value: -1.019281788849477.
# [I 2025-05-23 01:56:34,741] Trial 44 finished with value: -1.0203504659092042 and parameters: {'n_estimators': 255, 'learning_rate': 0.005922171508786121, 'max_depth': 4, 'num_leaves': 36, 'subsample': 0.7324149350438605, 'colsample_bytree': 0.7829804898240441, 'min_child_samples': 27, 'reg_alpha': 0.06937259794135109, 'reg_lambda': 9.787051827435187e-06}. Best is trial 41 with value: -1.019281788849477.
# [I 2025-05-23 01:56:35,503] Trial 45 finished with value: -1.0235188894425709 and parameters: {'n_estimators': 247, 'learning_rate': 0.008847181582191384, 'max_depth': 5, 'num_leaves': 35, 'subsample': 0.7370152941724023, 'colsample_bytree': 0.7841049428953812, 'min_child_samples': 25, 'reg_alpha': 8.055353792310946, 'reg_lambda': 9.30037576687202e-06}. Best is trial 41 with value: -1.019281788849477.
# [I 2025-05-23 01:56:36,097] Trial 46 finished with value: -1.0218234914574362 and parameters: {'n_estimators': 268, 'learning_rate': 0.010778281755387501, 'max_depth': 4, 'num_leaves': 31, 'subsample': 0.6813994923649845, 'colsample_bytree': 0.7033619301184758, 'min_child_samples': 23, 'reg_alpha': 0.658325542073957, 'reg_lambda': 0.0005161436893235575}. Best is trial 41 with value: -1.019281788849477.
# [I 2025-05-23 01:56:37,064] Trial 47 finished with value: -1.031176549833236 and parameters: {'n_estimators': 300, 'learning_rate': 0.005747773002352547, 'max_depth': 5, 'num_leaves': 15, 'subsample': 0.6527465681418106, 'colsample_bytree': 0.7905519548437174, 'min_child_samples': 5, 'reg_alpha': 0.0896704649916454, 'reg_lambda': 0.00014704837773044931}. Best is trial 41 with value: -1.019281788849477.
# [I 2025-05-23 01:56:37,562] Trial 48 finished with value: -1.0423565077846202 and parameters: {'n_estimators': 228, 'learning_rate': 0.036230563667408275, 'max_depth': 4, 'num_leaves': 37, 'subsample': 0.7232523281833036, 'colsample_bytree': 0.8241379827435251, 'min_child_samples': 27, 'reg_alpha': 0.005965681102847892, 'reg_lambda': 1.399133226521926e-05}. Best is trial 41 with value: -1.019281788849477.
# [I 2025-05-23 01:56:38,188] Trial 49 finished with value: -1.0222237894583601 and parameters: {'n_estimators': 211, 'learning_rate': 0.004633437643308699, 'max_depth': 5, 'num_leaves': 22, 'subsample': 0.6279124422488968, 'colsample_bytree': 0.7334144667870292, 'min_child_samples': 24, 'reg_alpha': 0.06781710359222153, 'reg_lambda': 1.1160669419708253e-07}. Best is trial 41 with value: -1.019281788849477.
# [I 2025-05-23 01:56:39,326] Trial 50 finished with value: -1.0261155476462367 and parameters: {'n_estimators': 270, 'learning_rate': 0.008372814798261125, 'max_depth': 8, 'num_leaves': 86, 'subsample': 0.7937676088253681, 'colsample_bytree': 0.7981794419888311, 'min_child_samples': 27, 'reg_alpha': 0.37008678930913824, 'reg_lambda': 1.919345744699567e-06}. Best is trial 41 with value: -1.019281788849477.
# [I 2025-05-23 01:56:40,005] Trial 51 finished with value: -1.0205631652921783 and parameters: {'n_estimators': 334, 'learning_rate': 0.007074409022736916, 'max_depth': 4, 'num_leaves': 26, 'subsample': 0.6964948900652428, 'colsample_bytree': 0.7646629703207921, 'min_child_samples': 30, 'reg_alpha': 0.03462294868578512, 'reg_lambda': 6.944065384697684e-07}. Best is trial 41 with value: -1.019281788849477.
# [I 2025-05-23 01:56:40,878] Trial 52 finished with value: -1.0201177435741553 and parameters: {'n_estimators': 361, 'learning_rate': 0.0035770709283153125, 'max_depth': 4, 'num_leaves': 19, 'subsample': 0.750996302676195, 'colsample_bytree': 0.777051354456439, 'min_child_samples': 29, 'reg_alpha': 1.925388407521612, 'reg_lambda': 6.754491549171384e-06}. Best is trial 41 with value: -1.019281788849477.
# [I 2025-05-23 01:56:41,699] Trial 53 finished with value: -1.0196801326458242 and parameters: {'n_estimators': 362, 'learning_rate': 0.0037024862669986333, 'max_depth': 4, 'num_leaves': 19, 'subsample': 0.7524719552048293, 'colsample_bytree': 0.7794286418656855, 'min_child_samples': 29, 'reg_alpha': 1.7480652506836447, 'reg_lambda': 8.851995872488657e-05}. Best is trial 41 with value: -1.019281788849477.
# [I 2025-05-23 01:56:42,850] Trial 54 finished with value: -1.021219361448496 and parameters: {'n_estimators': 360, 'learning_rate': 0.0034220346288501777, 'max_depth': 5, 'num_leaves': 19, 'subsample': 0.7496493745112905, 'colsample_bytree': 0.7487310094342653, 'min_child_samples': 29, 'reg_alpha': 2.490531466653053, 'reg_lambda': 8.864025630386182e-05}. Best is trial 41 with value: -1.019281788849477.
# [I 2025-05-23 01:56:45,083] Trial 55 finished with value: -1.0238143245994962 and parameters: {'n_estimators': 407, 'learning_rate': 0.004523731958445349, 'max_depth': 11, 'num_leaves': 29, 'subsample': 0.7722809784875652, 'colsample_bytree': 0.8123532056139809, 'min_child_samples': 26, 'reg_alpha': 1.3168420894653239, 'reg_lambda': 0.011508514456463411}. Best is trial 41 with value: -1.019281788849477.
# [I 2025-05-23 01:56:46,034] Trial 56 finished with value: -1.0200710003617284 and parameters: {'n_estimators': 364, 'learning_rate': 0.0036279270916148593, 'max_depth': 4, 'num_leaves': 18, 'subsample': 0.806167585660684, 'colsample_bytree': 0.7734235697259799, 'min_child_samples': 25, 'reg_alpha': 4.709981840990324, 'reg_lambda': 0.6658182990660539}. Best is trial 41 with value: -1.019281788849477.
# [I 2025-05-23 01:56:47,234] Trial 57 finished with value: -1.0210009144969576 and parameters: {'n_estimators': 367, 'learning_rate': 0.003569198655112993, 'max_depth': 5, 'num_leaves': 15, 'subsample': 0.8266429008766177, 'colsample_bytree': 0.6084542045182182, 'min_child_samples': 25, 'reg_alpha': 8.802419957993614, 'reg_lambda': 1.42550331195253}. Best is trial 41 with value: -1.019281788849477.
# [I 2025-05-23 01:56:47,982] Trial 58 finished with value: -1.0198522826200305 and parameters: {'n_estimators': 349, 'learning_rate': 0.0034759697989211824, 'max_depth': 4, 'num_leaves': 19, 'subsample': 0.8076080743818398, 'colsample_bytree': 0.8370607994568927, 'min_child_samples': 29, 'reg_alpha': 4.651393649901839, 'reg_lambda': 0.00031157834378742313}. Best is trial 41 with value: -1.019281788849477.
# [I 2025-05-23 01:56:49,193] Trial 59 finished with value: -1.0226357269309079 and parameters: {'n_estimators': 336, 'learning_rate': 0.001984738088271912, 'max_depth': 6, 'num_leaves': 18, 'subsample': 0.8107075052398544, 'colsample_bytree': 0.8283895456905037, 'min_child_samples': 16, 'reg_alpha': 4.146308896515539, 'reg_lambda': 0.004353570903614608}. Best is trial 41 with value: -1.019281788849477.
# [I 2025-05-23 01:56:50,092] Trial 60 finished with value: -1.0211753478664385 and parameters: {'n_estimators': 438, 'learning_rate': 0.004255783255902682, 'max_depth': 4, 'num_leaves': 29, 'subsample': 0.7957040411517049, 'colsample_bytree': 0.8480021924381417, 'min_child_samples': 23, 'reg_alpha': 0.47064679400962683, 'reg_lambda': 0.0003459938312205167}. Best is trial 41 with value: -1.019281788849477.
# [I 2025-05-23 01:56:51,185] Trial 61 finished with value: -1.0198579687163378 and parameters: {'n_estimators': 395, 'learning_rate': 0.003370771631107667, 'max_depth': 4, 'num_leaves': 20, 'subsample': 0.7779408528327354, 'colsample_bytree': 0.7720807161968537, 'min_child_samples': 29, 'reg_alpha': 1.1182807178717928, 'reg_lambda': 0.34309316356726866}. Best is trial 41 with value: -1.019281788849477.
# [I 2025-05-23 01:56:52,065] Trial 62 finished with value: -1.020671654631466 and parameters: {'n_estimators': 396, 'learning_rate': 0.002442379965208162, 'max_depth': 4, 'num_leaves': 24, 'subsample': 0.782313676251811, 'colsample_bytree': 0.7995645278431736, 'min_child_samples': 28, 'reg_alpha': 1.0084222306834048, 'reg_lambda': 0.1910895719972251}. Best is trial 41 with value: -1.019281788849477.
# [I 2025-05-23 01:56:53,044] Trial 63 finished with value: -1.020598762319262 and parameters: {'n_estimators': 350, 'learning_rate': 0.0032098888639887483, 'max_depth': 5, 'num_leaves': 32, 'subsample': 0.8020497701937684, 'colsample_bytree': 0.7277852575694186, 'min_child_samples': 25, 'reg_alpha': 4.064504654946466, 'reg_lambda': 0.44721518871596233}. Best is trial 41 with value: -1.019281788849477.
# [I 2025-05-23 01:56:54,055] Trial 64 finished with value: -1.0200717437799802 and parameters: {'n_estimators': 400, 'learning_rate': 0.0052495819393857425, 'max_depth': 4, 'num_leaves': 18, 'subsample': 0.7608120094340458, 'colsample_bytree': 0.703724718347004, 'min_child_samples': 29, 'reg_alpha': 0.21176993840197614, 'reg_lambda': 0.051207757830071775}. Best is trial 41 with value: -1.019281788849477.
# [I 2025-05-23 01:56:54,893] Trial 65 finished with value: -1.0205811990193039 and parameters: {'n_estimators': 373, 'learning_rate': 0.003686640667616397, 'max_depth': 4, 'num_leaves': 25, 'subsample': 0.7723211076816052, 'colsample_bytree': 0.7411274211250221, 'min_child_samples': 26, 'reg_alpha': 1.1038476289786537e-06, 'reg_lambda': 3.7645413376397605}. Best is trial 41 with value: -1.019281788849477.
# [I 2025-05-23 01:56:55,809] Trial 66 finished with value: -1.0255768083488412 and parameters: {'n_estimators': 305, 'learning_rate': 0.003073309319485505, 'max_depth': 5, 'num_leaves': 15, 'subsample': 0.841844363448695, 'colsample_bytree': 0.8164343864545378, 'min_child_samples': 10, 'reg_alpha': 2.497800260973067e-05, 'reg_lambda': 0.89104436805439}. Best is trial 41 with value: -1.019281788849477.
# [I 2025-05-23 01:56:57,260] Trial 67 finished with value: -1.0208208467409652 and parameters: {'n_estimators': 491, 'learning_rate': 0.0026154349773839887, 'max_depth': 5, 'num_leaves': 29, 'subsample': 0.7212249846399713, 'colsample_bytree': 0.837238595748044, 'min_child_samples': 28, 'reg_alpha': 3.3402622997060174, 'reg_lambda': 0.0062962536482565465}. Best is trial 41 with value: -1.019281788849477.
# [I 2025-05-23 01:56:58,354] Trial 68 finished with value: -1.0209079256195455 and parameters: {'n_estimators': 349, 'learning_rate': 0.004203485562564759, 'max_depth': 4, 'num_leaves': 21, 'subsample': 0.8261424035484556, 'colsample_bytree': 0.860572190658699, 'min_child_samples': 22, 'reg_alpha': 9.612491875947441, 'reg_lambda': 0.04603979326547657}. Best is trial 41 with value: -1.019281788849477.
# [I 2025-05-23 01:56:59,223] Trial 69 finished with value: -1.0215763272093283 and parameters: {'n_estimators': 421, 'learning_rate': 0.002181661567248128, 'max_depth': 4, 'num_leaves': 38, 'subsample': 0.7802449515234238, 'colsample_bytree': 0.7719667352893769, 'min_child_samples': 26, 'reg_alpha': 0.8274923477771532, 'reg_lambda': 0.0007007648387403593}. Best is trial 41 with value: -1.019281788849477.
# [I 2025-05-23 01:57:01,147] Trial 70 finished with value: -1.0275448625256831 and parameters: {'n_estimators': 391, 'learning_rate': 0.006212551205268239, 'max_depth': 9, 'num_leaves': 33, 'subsample': 0.7104214317082718, 'colsample_bytree': 0.6855761814836385, 'min_child_samples': 29, 'reg_alpha': 0.28961158590051445, 'reg_lambda': 2.6495793907807577e-05}. Best is trial 41 with value: -1.019281788849477.
# [I 2025-05-23 01:57:02,093] Trial 71 finished with value: -1.0197465363246823 and parameters: {'n_estimators': 410, 'learning_rate': 0.005403911251921129, 'max_depth': 4, 'num_leaves': 20, 'subsample': 0.7562843874385862, 'colsample_bytree': 0.6648570195458315, 'min_child_samples': 29, 'reg_alpha': 0.13607660574877675, 'reg_lambda': 0.06097705047461144}. Best is trial 41 with value: -1.019281788849477.
# [I 2025-05-23 01:57:02,772] Trial 72 finished with value: -1.0188989439609983 and parameters: {'n_estimators': 326, 'learning_rate': 0.005009685219485428, 'max_depth': 4, 'num_leaves': 19, 'subsample': 0.7434334237246669, 'colsample_bytree': 0.6490853347568275, 'min_child_samples': 30, 'reg_alpha': 0.147273666739766, 'reg_lambda': 0.43085913730150116}. Best is trial 72 with value: -1.0188989439609983.
# [I 2025-05-23 01:57:03,674] Trial 73 finished with value: -1.0193524376159104 and parameters: {'n_estimators': 455, 'learning_rate': 0.004804340810893759, 'max_depth': 4, 'num_leaves': 28, 'subsample': 0.7394364467640897, 'colsample_bytree': 0.6557036492996209, 'min_child_samples': 30, 'reg_alpha': 0.16279966621007635, 'reg_lambda': 0.2532962611700544}. Best is trial 72 with value: -1.0188989439609983.
# [I 2025-05-23 01:57:04,817] Trial 74 finished with value: -1.024066292271289 and parameters: {'n_estimators': 462, 'learning_rate': 0.007942635288563784, 'max_depth': 4, 'num_leaves': 27, 'subsample': 0.7416315399886289, 'colsample_bytree': 0.6566622650858585, 'min_child_samples': 30, 'reg_alpha': 0.12209128195381468, 'reg_lambda': 0.1309404913990688}. Best is trial 72 with value: -1.0188989439609983.
# [I 2025-05-23 01:57:06,046] Trial 75 finished with value: -1.0223458517556367 and parameters: {'n_estimators': 434, 'learning_rate': 0.005436010255581508, 'max_depth': 5, 'num_leaves': 20, 'subsample': 0.7569369515275695, 'colsample_bytree': 0.6403655560327576, 'min_child_samples': 30, 'reg_alpha': 0.002562883936376818, 'reg_lambda': 0.2616693073716026}. Best is trial 72 with value: -1.0188989439609983.
# [I 2025-05-23 01:57:06,703] Trial 76 finished with value: -1.02000034945393 and parameters: {'n_estimators': 284, 'learning_rate': 0.004529612458678103, 'max_depth': 4, 'num_leaves': 23, 'subsample': 0.7296004423394122, 'colsample_bytree': 0.6724974870072528, 'min_child_samples': 29, 'reg_alpha': 0.13726496892819443, 'reg_lambda': 2.0771994073907427}. Best is trial 72 with value: -1.0188989439609983.
# [I 2025-05-23 01:57:07,532] Trial 77 finished with value: -1.0222247477985698 and parameters: {'n_estimators': 466, 'learning_rate': 0.006504320930447806, 'max_depth': 4, 'num_leaves': 17, 'subsample': 0.7439520012511232, 'colsample_bytree': 0.6222439732436085, 'min_child_samples': 30, 'reg_alpha': 0.014967558650970924, 'reg_lambda': 0.40976312378181046}. Best is trial 72 with value: -1.0188989439609983.
# [I 2025-05-23 01:57:08,972] Trial 78 finished with value: -1.0214690554258579 and parameters: {'n_estimators': 497, 'learning_rate': 0.004049843298797736, 'max_depth': 5, 'num_leaves': 24, 'subsample': 0.716266630517843, 'colsample_bytree': 0.6333272488749018, 'min_child_samples': 28, 'reg_alpha': 0.00782757365188045, 'reg_lambda': 0.00023066712810762804}. Best is trial 72 with value: -1.0188989439609983.
# [I 2025-05-23 01:57:09,640] Trial 79 finished with value: -1.0191518196145615 and parameters: {'n_estimators': 329, 'learning_rate': 0.004822854035851098, 'max_depth': 4, 'num_leaves': 28, 'subsample': 0.7723705970546589, 'colsample_bytree': 0.6055815777643692, 'min_child_samples': 28, 'reg_alpha': 0.4495227386790769, 'reg_lambda': 0.08542936013011655}. Best is trial 72 with value: -1.0188989439609983.
# [I 2025-05-23 01:57:10,322] Trial 80 finished with value: -1.0203081266467853 and parameters: {'n_estimators': 329, 'learning_rate': 0.0047938006019727876, 'max_depth': 4, 'num_leaves': 27, 'subsample': 0.7661832116348126, 'colsample_bytree': 0.6084946975499667, 'min_child_samples': 29, 'reg_alpha': 0.518520707664586, 'reg_lambda': 8.254193247341863}. Best is trial 72 with value: -1.0188989439609983.
# [I 2025-05-23 01:57:10,946] Trial 81 finished with value: -1.0192685182489738 and parameters: {'n_estimators': 297, 'learning_rate': 0.005242275634019038, 'max_depth': 4, 'num_leaves': 21, 'subsample': 0.7857911468677564, 'colsample_bytree': 0.6699542634174491, 'min_child_samples': 28, 'reg_alpha': 1.1840471252900062, 'reg_lambda': 0.10175912921950192}. Best is trial 72 with value: -1.0188989439609983.
# [I 2025-05-23 01:57:11,620] Trial 82 finished with value: -1.0191826167332476 and parameters: {'n_estimators': 326, 'learning_rate': 0.005270111560301502, 'max_depth': 4, 'num_leaves': 21, 'subsample': 0.7791847415342575, 'colsample_bytree': 0.667166626288875, 'min_child_samples': 28, 'reg_alpha': 1.1056584548084305, 'reg_lambda': 0.11002496465019362}. Best is trial 72 with value: -1.0188989439609983.
# [I 2025-05-23 01:57:12,596] Trial 83 finished with value: -1.0207411531034434 and parameters: {'n_estimators': 299, 'learning_rate': 0.005485227605932502, 'max_depth': 5, 'num_leaves': 22, 'subsample': 0.7918369847120842, 'colsample_bytree': 0.6668887582080034, 'min_child_samples': 28, 'reg_alpha': 0.25126551833146776, 'reg_lambda': 0.1176618381038289}. Best is trial 72 with value: -1.0188989439609983.
# [I 2025-05-23 01:57:13,323] Trial 84 finished with value: -1.0255024453103363 and parameters: {'n_estimators': 325, 'learning_rate': 0.00996781525669791, 'max_depth': 4, 'num_leaves': 16, 'subsample': 0.7633104217484749, 'colsample_bytree': 0.6469996475967004, 'min_child_samples': 13, 'reg_alpha': 2.0571272747217617, 'reg_lambda': 0.02330870922843481}. Best is trial 72 with value: -1.0188989439609983.
# [I 2025-05-23 01:57:13,992] Trial 85 finished with value: -1.0194324636012495 and parameters: {'n_estimators': 312, 'learning_rate': 0.004914059761135311, 'max_depth': 4, 'num_leaves': 27, 'subsample': 0.7522568258643185, 'colsample_bytree': 0.6011357337333578, 'min_child_samples': 30, 'reg_alpha': 0.4529747405842824, 'reg_lambda': 0.05508696070393997}. Best is trial 72 with value: -1.0188989439609983.
# [I 2025-05-23 01:57:14,762] Trial 86 finished with value: -1.0216025527237034 and parameters: {'n_estimators': 308, 'learning_rate': 0.007483138893222164, 'max_depth': 5, 'num_leaves': 25, 'subsample': 0.7579781197178684, 'colsample_bytree': 0.6212319825179999, 'min_child_samples': 30, 'reg_alpha': 0.3730594493316583, 'reg_lambda': 0.0780339782369882}. Best is trial 72 with value: -1.0188989439609983.
# [I 2025-05-23 01:57:16,077] Trial 87 finished with value: -1.0219585578829076 and parameters: {'n_estimators': 276, 'learning_rate': 0.004834736389313414, 'max_depth': 10, 'num_leaves': 34, 'subsample': 0.7884512481640271, 'colsample_bytree': 0.6770759834721717, 'min_child_samples': 27, 'reg_alpha': 0.052427354669471654, 'reg_lambda': 0.01459301608550728}. Best is trial 72 with value: -1.0188989439609983.
# [I 2025-05-23 01:57:16,715] Trial 88 finished with value: -1.0197075568169982 and parameters: {'n_estimators': 307, 'learning_rate': 0.006786852955133262, 'max_depth': 4, 'num_leaves': 23, 'subsample': 0.7502542635916027, 'colsample_bytree': 0.6582581045881035, 'min_child_samples': 30, 'reg_alpha': 0.7329114044857564, 'reg_lambda': 0.08114848180958888}. Best is trial 72 with value: -1.0188989439609983.
# [I 2025-05-23 01:57:17,345] Trial 89 finished with value: -1.0199256159537788 and parameters: {'n_estimators': 311, 'learning_rate': 0.006624432969650336, 'max_depth': 4, 'num_leaves': 27, 'subsample': 0.7423446644902495, 'colsample_bytree': 0.6003851680251605, 'min_child_samples': 30, 'reg_alpha': 0.658611233944355, 'reg_lambda': 0.031171729866342528}. Best is trial 72 with value: -1.0188989439609983.
# [I 2025-05-23 01:57:18,378] Trial 90 finished with value: -1.0213531263969284 and parameters: {'n_estimators': 329, 'learning_rate': 0.004411204892145988, 'max_depth': 6, 'num_leaves': 79, 'subsample': 0.773201393602009, 'colsample_bytree': 0.6269567373851183, 'min_child_samples': 28, 'reg_alpha': 1.8619130400617313e-08, 'reg_lambda': 0.1975336446536574}. Best is trial 72 with value: -1.0188989439609983.
# [I 2025-05-23 01:57:19,109] Trial 91 finished with value: -1.0191205028121595 and parameters: {'n_estimators': 296, 'learning_rate': 0.005139244984507976, 'max_depth': 4, 'num_leaves': 23, 'subsample': 0.7485279838793564, 'colsample_bytree': 0.6575785183383247, 'min_child_samples': 30, 'reg_alpha': 0.1674838248125341, 'reg_lambda': 0.08638800796158902}. Best is trial 72 with value: -1.0188989439609983.
# [I 2025-05-23 01:57:19,887] Trial 92 finished with value: -1.0200825335985924 and parameters: {'n_estimators': 290, 'learning_rate': 0.004027984694761795, 'max_depth': 4, 'num_leaves': 23, 'subsample': 0.7229174969221439, 'colsample_bytree': 0.6572950191588282, 'min_child_samples': 30, 'reg_alpha': 1.0510055436849581, 'reg_lambda': 0.10789653980060708}. Best is trial 72 with value: -1.0188989439609983.
# [I 2025-05-23 01:57:20,543] Trial 93 finished with value: -1.0196398244288478 and parameters: {'n_estimators': 295, 'learning_rate': 0.005901564940639807, 'max_depth': 4, 'num_leaves': 28, 'subsample': 0.7494657997983896, 'colsample_bytree': 0.639242737788976, 'min_child_samples': 28, 'reg_alpha': 0.3694681747501489, 'reg_lambda': 0.7174953607379797}. Best is trial 72 with value: -1.0188989439609983.
# [I 2025-05-23 01:57:21,120] Trial 94 finished with value: -1.019540541553098 and parameters: {'n_estimators': 262, 'learning_rate': 0.00586860083920208, 'max_depth': 4, 'num_leaves': 30, 'subsample': 0.7071211546482304, 'colsample_bytree': 0.6386693064638843, 'min_child_samples': 27, 'reg_alpha': 0.09231634250393657, 'reg_lambda': 0.8518952204891761}. Best is trial 72 with value: -1.0188989439609983.
# [I 2025-05-23 01:57:21,670] Trial 95 finished with value: -1.0196766367052241 and parameters: {'n_estimators': 264, 'learning_rate': 0.0059546597969712105, 'max_depth': 4, 'num_leaves': 39, 'subsample': 0.701508095828796, 'colsample_bytree': 0.6394801103191893, 'min_child_samples': 28, 'reg_alpha': 0.019862789554904895, 'reg_lambda': 0.8971424105022388}. Best is trial 72 with value: -1.0188989439609983.
# [I 2025-05-23 01:57:22,513] Trial 96 finished with value: -1.021104970638951 and parameters: {'n_estimators': 244, 'learning_rate': 0.007921286467019199, 'max_depth': 5, 'num_leaves': 31, 'subsample': 0.6806953979110973, 'colsample_bytree': 0.6118864559283513, 'min_child_samples': 27, 'reg_alpha': 0.09085806977282522, 'reg_lambda': 2.219133405194523}. Best is trial 72 with value: -1.0188989439609983.
# [I 2025-05-23 01:57:23,152] Trial 97 finished with value: -1.0197695087750809 and parameters: {'n_estimators': 278, 'learning_rate': 0.005045279841978648, 'max_depth': 4, 'num_leaves': 34, 'subsample': 0.7318618003248536, 'colsample_bytree': 0.6920156121732363, 'min_child_samples': 27, 'reg_alpha': 0.0532761489019406, 'reg_lambda': 0.6790930610983408}. Best is trial 72 with value: -1.0188989439609983.
# [I 2025-05-23 01:57:23,822] Trial 98 finished with value: -1.020983571115457 and parameters: {'n_estimators': 256, 'learning_rate': 0.006163332743071002, 'max_depth': 5, 'num_leaves': 28, 'subsample': 0.704321366956122, 'colsample_bytree': 0.6438630348738732, 'min_child_samples': 26, 'reg_alpha': 0.1850729385788689, 'reg_lambda': 0.03290730348893944}. Best is trial 72 with value: -1.0188989439609983.
# [I 2025-05-23 01:57:24,429] Trial 99 finished with value: -1.0200030306852361 and parameters: {'n_estimators': 297, 'learning_rate': 0.00561946479219663, 'max_depth': 4, 'num_leaves': 30, 'subsample': 0.7119974526503451, 'colsample_bytree': 0.6162384230071192, 'min_child_samples': 28, 'reg_alpha': 0.2956624021527813, 'reg_lambda': 0.26502152431499243}. Best is trial 72 with value: -1.0188989439609983.
# [I 2025-05-23 01:57:25,175] Trial 100 finished with value: -1.020370492512657 and parameters: {'n_estimators': 274, 'learning_rate': 0.005007667002934573, 'max_depth': 5, 'num_leaves': 42, 'subsample': 0.7398682951298776, 'colsample_bytree': 0.6320886003212048, 'min_child_samples': 26, 'reg_alpha': 0.4051029362739247, 'reg_lambda': 1.3730846866344053}. Best is trial 72 with value: -1.0188989439609983.
# [I 2025-05-23 01:57:25,675] Trial 101 finished with value: -1.0199943077077376 and parameters: {'n_estimators': 230, 'learning_rate': 0.00612026656121054, 'max_depth': 4, 'num_leaves': 25, 'subsample': 0.6863211467740885, 'colsample_bytree': 0.6463416132026099, 'min_child_samples': 28, 'reg_alpha': 0.025339823224881382, 'reg_lambda': 0.8756693757270485}. Best is trial 72 with value: -1.0188989439609983.
# [I 2025-05-23 01:57:26,238] Trial 102 finished with value: -1.0197033225158072 and parameters: {'n_estimators': 262, 'learning_rate': 0.0057305720071938225, 'max_depth': 4, 'num_leaves': 38, 'subsample': 0.7178106688252714, 'colsample_bytree': 0.6350187796452126, 'min_child_samples': 28, 'reg_alpha': 0.10465777613125275, 'reg_lambda': 0.5485792868616235}. Best is trial 72 with value: -1.0188989439609983.
# [I 2025-05-23 01:57:26,779] Trial 103 finished with value: -1.0235083543982975 and parameters: {'n_estimators': 177, 'learning_rate': 0.0074942688916096985, 'max_depth': 4, 'num_leaves': 31, 'subsample': 0.6686782161872926, 'colsample_bytree': 0.6003389411153823, 'min_child_samples': 7, 'reg_alpha': 0.019949469465327715, 'reg_lambda': 4.50590518170187}. Best is trial 72 with value: -1.0188989439609983.
# [I 2025-05-23 01:57:27,379] Trial 104 finished with value: -1.0200666557354354 and parameters: {'n_estimators': 294, 'learning_rate': 0.004628211596564776, 'max_depth': 4, 'num_leaves': 28, 'subsample': 0.703219287716925, 'colsample_bytree': 0.6404727174265169, 'min_child_samples': 27, 'reg_alpha': 0.04577318939529501, 'reg_lambda': 0.28121001183544064}. Best is trial 72 with value: -1.0188989439609983.
# [I 2025-05-23 01:57:27,952] Trial 105 finished with value: -1.0186656084721601 and parameters: {'n_estimators': 266, 'learning_rate': 0.006877433950028496, 'max_depth': 4, 'num_leaves': 26, 'subsample': 0.730709856736536, 'colsample_bytree': 0.6546175138047936, 'min_child_samples': 29, 'reg_alpha': 0.1815537849178006, 'reg_lambda': 0.18774253048914655}. Best is trial 105 with value: -1.0186656084721601.
# [I 2025-05-23 01:57:28,617] Trial 106 finished with value: -1.0198263335667428 and parameters: {'n_estimators': 315, 'learning_rate': 0.007060199628186672, 'max_depth': 4, 'num_leaves': 27, 'subsample': 0.7657299015733252, 'colsample_bytree': 0.6823437967083188, 'min_child_samples': 30, 'reg_alpha': 0.16571058381666243, 'reg_lambda': 0.08441194581940316}. Best is trial 105 with value: -1.0186656084721601.
# [I 2025-05-23 01:57:29,244] Trial 107 finished with value: -1.0209257930513247 and parameters: {'n_estimators': 282, 'learning_rate': 0.009641970663295578, 'max_depth': 4, 'num_leaves': 99, 'subsample': 0.7282259081607388, 'colsample_bytree': 0.656467781055349, 'min_child_samples': 29, 'reg_alpha': 0.49877172150976323, 'reg_lambda': 0.1871646245470261}. Best is trial 105 with value: -1.0186656084721601.
# [I 2025-05-23 01:57:29,948] Trial 108 finished with value: -1.0191232654515356 and parameters: {'n_estimators': 341, 'learning_rate': 0.005195128494973781, 'max_depth': 4, 'num_leaves': 21, 'subsample': 0.7842054770643937, 'colsample_bytree': 0.6944888018177091, 'min_child_samples': 29, 'reg_alpha': 1.416314307184811, 'reg_lambda': 1.3903397730831675}. Best is trial 105 with value: -1.0186656084721601.
# [I 2025-05-23 01:57:31,261] Trial 109 finished with value: -1.020210326612961 and parameters: {'n_estimators': 344, 'learning_rate': 0.005108817536607452, 'max_depth': 8, 'num_leaves': 21, 'subsample': 0.8005270903928114, 'colsample_bytree': 0.6736055603166159, 'min_child_samples': 29, 'reg_alpha': 2.5537594654881746, 'reg_lambda': 1.4479262505852653}. Best is trial 105 with value: -1.0186656084721601.
# [I 2025-05-23 01:57:31,951] Trial 110 finished with value: -1.031766884626875 and parameters: {'n_estimators': 338, 'learning_rate': 0.01894738353968442, 'max_depth': 4, 'num_leaves': 17, 'subsample': 0.7813897003694096, 'colsample_bytree': 0.6992166841613975, 'min_child_samples': 30, 'reg_alpha': 1.5647316960001092, 'reg_lambda': 0.008228858363234743}. Best is trial 105 with value: -1.0186656084721601.
# [I 2025-05-23 01:57:32,575] Trial 111 finished with value: -1.0201228249611032 and parameters: {'n_estimators': 302, 'learning_rate': 0.00422862588390241, 'max_depth': 4, 'num_leaves': 25, 'subsample': 0.744712204170202, 'colsample_bytree': 0.6508451102751622, 'min_child_samples': 29, 'reg_alpha': 0.290972127082881, 'reg_lambda': 0.14752349680202798}. Best is trial 105 with value: -1.0186656084721601.
# [I 2025-05-23 01:57:33,241] Trial 112 finished with value: -1.019793376623697 and parameters: {'n_estimators': 325, 'learning_rate': 0.006420604880932298, 'max_depth': 4, 'num_leaves': 24, 'subsample': 0.7855414476386469, 'colsample_bytree': 0.6659321373516703, 'min_child_samples': 27, 'reg_alpha': 0.06947625527362358, 'reg_lambda': 2.619687350303702}. Best is trial 105 with value: -1.0186656084721601.
# [I 2025-05-23 01:57:33,785] Trial 113 finished with value: -1.0209515206682063 and parameters: {'n_estimators': 249, 'learning_rate': 0.0038982808172672765, 'max_depth': 4, 'num_leaves': 21, 'subsample': 0.7755346995768823, 'colsample_bytree': 0.68853559230925, 'min_child_samples': 28, 'reg_alpha': 0.8095781092983657, 'reg_lambda': 0.4056647267358906}. Best is trial 105 with value: -1.0186656084721601.
# [I 2025-05-23 01:57:34,597] Trial 114 finished with value: -1.0199181919579603 and parameters: {'n_estimators': 313, 'learning_rate': 0.004658877069748142, 'max_depth': 4, 'num_leaves': 30, 'subsample': 0.8173340546417383, 'colsample_bytree': 0.6204059736405619, 'min_child_samples': 29, 'reg_alpha': 0.20747433344878258, 'reg_lambda': 1.0589045842944143}. Best is trial 105 with value: -1.0186656084721601.
# [I 2025-05-23 01:57:35,303] Trial 115 finished with value: -1.0206068581312882 and parameters: {'n_estimators': 235, 'learning_rate': 0.005467558499441623, 'max_depth': 5, 'num_leaves': 26, 'subsample': 0.7350112943140301, 'colsample_bytree': 0.7155826986859443, 'min_child_samples': 30, 'reg_alpha': 1.328375943470494, 'reg_lambda': 0.05227925090583415}. Best is trial 105 with value: -1.0186656084721601.
# [I 2025-05-23 01:57:35,929] Trial 116 finished with value: -1.0202894894012107 and parameters: {'n_estimators': 290, 'learning_rate': 0.005276615684577175, 'max_depth': 4, 'num_leaves': 32, 'subsample': 0.7528157673054185, 'colsample_bytree': 0.696895355508512, 'min_child_samples': 28, 'reg_alpha': 0.4285213424946165, 'reg_lambda': 7.405189962023965}. Best is trial 105 with value: -1.0186656084721601.
# ...
# [I 2025-05-23 01:58:13,161] Trial 162 finished with value: -1.0214321728336162 and parameters: {'n_estimators': 343, 'learning_rate': 0.007404487315172345, 'max_depth': 4, 'num_leaves': 23, 'subsample': 0.7549732115228583, 'colsample_bytree': 0.9777643375719862, 'min_child_samples': 29, 'reg_alpha': 1.475180216680813, 'reg_lambda': 0.023864434902206657}. Best is trial 105 with value: -1.0186656084721601.
# [I 2025-05-23 01:58:13,840] Trial 163 finished with value: -1.0194698546124545 and parameters: {'n_estimators': 322, 'learning_rate': 0.006551145149989571, 'max_depth': 4, 'num_leaves': 17, 'subsample': 0.7004531202864651, 'colsample_bytree': 0.6380146328562519, 'min_child_samples': 28, 'reg_alpha': 0.34750621435717394, 'reg_lambda': 0.17714229769911646}. Best is trial 105 with value: -1.0186656084721601.
# [I 2025-05-23 01:58:14,539] Trial 164 finished with value: -1.0192974102535328 and parameters: {'n_estimators': 310, 'learning_rate': 0.005196359086972033, 'max_depth': 4, 'num_leaves': 19, 'subsample': 0.7863022738403693, 'colsample_bytree': 0.668730480102776, 'min_child_samples': 30, 'reg_alpha': 4.213411414871591, 'reg_lambda': 0.0012466137861666437}. Best is trial 105 with value: -1.0186656084721601.
# [I 2025-05-23 01:58:15,200] Trial 165 finished with value: -1.0192428629061818 and parameters: {'n_estimators': 300, 'learning_rate': 0.005185952798774022, 'max_depth': 4, 'num_leaves': 18, 'subsample': 0.6854435265816635, 'colsample_bytree': 0.6911984830111682, 'min_child_samples': 30, 'reg_alpha': 5.160636156031082, 'reg_lambda': 0.130761359152163}. Best is trial 105 with value: -1.0186656084721601.
# [I 2025-05-23 01:58:15,855] Trial 166 finished with value: -1.0188994165903709 and parameters: {'n_estimators': 299, 'learning_rate': 0.005081815141225345, 'max_depth': 4, 'num_leaves': 19, 'subsample': 0.6626169663423858, 'colsample_bytree': 0.6879260335501218, 'min_child_samples': 30, 'reg_alpha': 3.858480734130946, 'reg_lambda': 0.011230151299485264}. Best is trial 105 with value: -1.0186656084721601.
# [I 2025-05-23 01:58:16,549] Trial 167 finished with value: -1.0188732598550057 and parameters: {'n_estimators': 304, 'learning_rate': 0.005138910792640075, 'max_depth': 4, 'num_leaves': 19, 'subsample': 0.6599679102451779, 'colsample_bytree': 0.6901777990156533, 'min_child_samples': 30, 'reg_alpha': 4.524236048706349, 'reg_lambda': 0.012736359823860014}. Best is trial 105 with value: -1.0186656084721601.
# [I 2025-05-23 01:58:17,231] Trial 168 finished with value: -1.019466946220924 and parameters: {'n_estimators': 298, 'learning_rate': 0.004381829172506585, 'max_depth': 4, 'num_leaves': 20, 'subsample': 0.6634438143175467, 'colsample_bytree': 0.7083282981131469, 'min_child_samples': 30, 'reg_alpha': 5.478121653099889, 'reg_lambda': 0.08714816877131193}. Best is trial 105 with value: -1.0186656084721601.
# [I 2025-05-23 01:58:17,862] Trial 169 finished with value: -1.0196577747289794 and parameters: {'n_estimators': 281, 'learning_rate': 0.004718261764707428, 'max_depth': 4, 'num_leaves': 15, 'subsample': 0.6587879512818982, 'colsample_bytree': 0.6868759066785186, 'min_child_samples': 30, 'reg_alpha': 6.810849352222385, 'reg_lambda': 0.020194665924360134}. Best is trial 105 with value: -1.0186656084721601.
# [I 2025-05-23 01:58:18,641] Trial 170 finished with value: -1.0207442087083696 and parameters: {'n_estimators': 302, 'learning_rate': 0.004999417868348154, 'max_depth': 5, 'num_leaves': 21, 'subsample': 0.636946910763378, 'colsample_bytree': 0.6940634371858232, 'min_child_samples': 30, 'reg_alpha': 0.000695887366313042, 'reg_lambda': 0.006946365765064706}. Best is trial 105 with value: -1.0186656084721601.
# [I 2025-05-23 01:58:19,308] Trial 171 finished with value: -1.0201847516391964 and parameters: {'n_estimators': 308, 'learning_rate': 0.005295276039847105, 'max_depth': 4, 'num_leaves': 19, 'subsample': 0.6411111804810822, 'colsample_bytree': 0.6820310790094422, 'min_child_samples': 30, 'reg_alpha': 9.68924372703397, 'reg_lambda': 0.0024402038470780004}. Best is trial 105 with value: -1.0186656084721601.
# [I 2025-05-23 01:58:19,996] Trial 172 finished with value: -1.0191922682659678 and parameters: {'n_estimators': 289, 'learning_rate': 0.005101880982876055, 'max_depth': 4, 'num_leaves': 17, 'subsample': 0.6906277883400025, 'colsample_bytree': 0.7021123358316494, 'min_child_samples': 30, 'reg_alpha': 3.875678600919346, 'reg_lambda': 0.009003099281895698}. Best is trial 105 with value: -1.0186656084721601.
# [I 2025-05-23 01:58:20,666] Trial 173 finished with value: -1.0192237072181691 and parameters: {'n_estimators': 291, 'learning_rate': 0.004094855588211506, 'max_depth': 4, 'num_leaves': 18, 'subsample': 0.6814436490685218, 'colsample_bytree': 0.7013056916644911, 'min_child_samples': 30, 'reg_alpha': 5.1622542224708114, 'reg_lambda': 0.011075850852739827}. Best is trial 105 with value: -1.0186656084721601.
# [I 2025-05-23 01:58:21,429] Trial 174 finished with value: -1.0196255383373214 and parameters: {'n_estimators': 290, 'learning_rate': 0.004009301748231778, 'max_depth': 4, 'num_leaves': 17, 'subsample': 0.6889883121286335, 'colsample_bytree': 0.7185106374629034, 'min_child_samples': 30, 'reg_alpha': 3.3137438180115946, 'reg_lambda': 0.012945979967207479}. Best is trial 105 with value: -1.0186656084721601.
# [I 2025-05-23 01:58:22,133] Trial 175 finished with value: -1.0193839455219542 and parameters: {'n_estimators': 284, 'learning_rate': 0.004435887202191438, 'max_depth': 4, 'num_leaves': 18, 'subsample': 0.6763866580463905, 'colsample_bytree': 0.7017304219140906, 'min_child_samples': 30, 'reg_alpha': 4.324515093927042, 'reg_lambda': 0.00871805403000301}. Best is trial 105 with value: -1.0186656084721601.
# [I 2025-05-23 01:58:22,756] Trial 176 finished with value: -1.0198771946767216 and parameters: {'n_estimators': 269, 'learning_rate': 0.004731472343302111, 'max_depth': 4, 'num_leaves': 15, 'subsample': 0.6586442008955414, 'colsample_bytree': 0.693572934990827, 'min_child_samples': 30, 'reg_alpha': 7.027319891366312, 'reg_lambda': 0.012151203550312413}. Best is trial 105 with value: -1.0186656084721601.
# [I 2025-05-23 01:58:23,425] Trial 177 finished with value: -1.0202116625444844 and parameters: {'n_estimators': 295, 'learning_rate': 0.004081302624994046, 'max_depth': 4, 'num_leaves': 21, 'subsample': 0.6841179315677054, 'colsample_bytree': 0.6865468514545173, 'min_child_samples': 29, 'reg_alpha': 1.9770275821754826, 'reg_lambda': 0.04920408391731394}. Best is trial 105 with value: -1.0186656084721601.
# [I 2025-05-23 01:58:24,070] Trial 178 finished with value: -1.0195429544660173 and parameters: {'n_estimators': 276, 'learning_rate': 0.005051033703128206, 'max_depth': 4, 'num_leaves': 19, 'subsample': 0.6875663153562018, 'colsample_bytree': 0.7129007490745406, 'min_child_samples': 30, 'reg_alpha': 3.4851863763558897, 'reg_lambda': 0.003461925173227433}. Best is trial 105 with value: -1.0186656084721601.
# [I 2025-05-23 01:58:24,747] Trial 179 finished with value: -1.0193763162304414 and parameters: {'n_estimators': 300, 'learning_rate': 0.0061864186846956135, 'max_depth': 4, 'num_leaves': 17, 'subsample': 0.6678116517143811, 'colsample_bytree': 0.7257917394634699, 'min_child_samples': 29, 'reg_alpha': 1.2533304780862886, 'reg_lambda': 0.018781026630595672}. Best is trial 105 with value: -1.0186656084721601.
# [I 2025-05-23 01:58:25,436] Trial 180 finished with value: -1.0193817866445392 and parameters: {'n_estimators': 311, 'learning_rate': 0.005464631733757171, 'max_depth': 4, 'num_leaves': 23, 'subsample': 0.6518858382948466, 'colsample_bytree': 0.6785139697162332, 'min_child_samples': 30, 'reg_alpha': 0.8125193402033547, 'reg_lambda': 0.004708643520745213}. Best is trial 105 with value: -1.0186656084721601.
# [I 2025-05-23 01:58:26,077] Trial 181 finished with value: -1.0193028709886511 and parameters: {'n_estimators': 284, 'learning_rate': 0.005878904751269894, 'max_depth': 4, 'num_leaves': 19, 'subsample': 0.6688021967222204, 'colsample_bytree': 0.7026262885917117, 'min_child_samples': 28, 'reg_alpha': 1.6852712135656653, 'reg_lambda': 0.009272173415992147}. Best is trial 105 with value: -1.0186656084721601.
# [I 2025-05-23 01:58:26,715] Trial 182 finished with value: -1.0199398476549242 and parameters: {'n_estimators': 290, 'learning_rate': 0.004939339350176738, 'max_depth': 4, 'num_leaves': 21, 'subsample': 0.6926105842853529, 'colsample_bytree': 0.6929586843530098, 'min_child_samples': 29, 'reg_alpha': 5.5312905510879595, 'reg_lambda': 0.02558372602501134}. Best is trial 105 with value: -1.0186656084721601.
# [I 2025-05-23 01:58:27,367] Trial 183 finished with value: -1.0207481828399736 and parameters: {'n_estimators': 297, 'learning_rate': 0.004330086453210704, 'max_depth': 4, 'num_leaves': 25, 'subsample': 0.6809062151785353, 'colsample_bytree': 0.7060673230726676, 'min_child_samples': 28, 'reg_alpha': 8.951833242094379, 'reg_lambda': 0.06342818661510582}. Best is trial 105 with value: -1.0186656084721601.
# [I 2025-05-23 01:58:27,996] Trial 184 finished with value: -1.019094810119319 and parameters: {'n_estimators': 270, 'learning_rate': 0.005353085171405769, 'max_depth': 4, 'num_leaves': 16, 'subsample': 0.6535333216852677, 'colsample_bytree': 0.6733159155215435, 'min_child_samples': 30, 'reg_alpha': 4.002500221083461, 'reg_lambda': 0.0055636454791942675}. Best is trial 105 with value: -1.0186656084721601.
# [I 2025-05-23 01:58:28,640] Trial 185 finished with value: -1.0191522679506178 and parameters: {'n_estimators': 269, 'learning_rate': 0.0053785228559653266, 'max_depth': 4, 'num_leaves': 16, 'subsample': 0.6516880406444169, 'colsample_bytree': 0.6761166958403426, 'min_child_samples': 30, 'reg_alpha': 3.8027521340856816, 'reg_lambda': 0.004510982468552833}. Best is trial 105 with value: -1.0186656084721601.
# [I 2025-05-23 01:58:29,272] Trial 186 finished with value: -1.0191765695837758 and parameters: {'n_estimators': 267, 'learning_rate': 0.004650242528986025, 'max_depth': 4, 'num_leaves': 16, 'subsample': 0.6472492921866184, 'colsample_bytree': 0.6857248606282061, 'min_child_samples': 30, 'reg_alpha': 3.8135877967209155, 'reg_lambda': 0.004995320227632281}. Best is trial 105 with value: -1.0186656084721601.
# [I 2025-05-23 01:58:29,880] Trial 187 finished with value: -1.0205042194686598 and parameters: {'n_estimators': 268, 'learning_rate': 0.003630197660319493, 'max_depth': 4, 'num_leaves': 16, 'subsample': 0.6518176097490673, 'colsample_bytree': 0.6736124712448973, 'min_child_samples': 30, 'reg_alpha': 2.9740195546809343, 'reg_lambda': 0.00531351380703331}. Best is trial 105 with value: -1.0186656084721601.
# [I 2025-05-23 01:58:30,794] Trial 188 finished with value: -1.01948772986933 and parameters: {'n_estimators': 250, 'learning_rate': 0.004627061800105126, 'max_depth': 9, 'num_leaves': 15, 'subsample': 0.643420409868569, 'colsample_bytree': 0.6840882341278403, 'min_child_samples': 29, 'reg_alpha': 3.9634684077453133, 'reg_lambda': 0.0018920769294240628}. Best is trial 105 with value: -1.0186656084721601.
# [I 2025-05-23 01:58:31,402] Trial 189 finished with value: -1.019559832782706 and parameters: {'n_estimators': 270, 'learning_rate': 0.0059434203048961244, 'max_depth': 4, 'num_leaves': 16, 'subsample': 0.6200731136644425, 'colsample_bytree': 0.6543126315261122, 'min_child_samples': 30, 'reg_alpha': 1.9063508995104559, 'reg_lambda': 0.006024462397611639}. Best is trial 105 with value: -1.0186656084721601.
# [I 2025-05-23 01:58:32,006] Trial 190 finished with value: -1.019954206271029 and parameters: {'n_estimators': 258, 'learning_rate': 0.00411682783018883, 'max_depth': 4, 'num_leaves': 17, 'subsample': 0.646638380172791, 'colsample_bytree': 0.6795534987455057, 'min_child_samples': 30, 'reg_alpha': 2.9439648187906395, 'reg_lambda': 0.0027672927069976277}. Best is trial 105 with value: -1.0186656084721601.
# [I 2025-05-23 01:58:32,657] Trial 191 finished with value: -1.0190541249334146 and parameters: {'n_estimators': 279, 'learning_rate': 0.005389333547319637, 'max_depth': 4, 'num_leaves': 18, 'subsample': 0.6293638762546826, 'colsample_bytree': 0.6971467205122014, 'min_child_samples': 30, 'reg_alpha': 5.536563432983938, 'reg_lambda': 0.013551531870549222}. Best is trial 105 with value: -1.0186656084721601.
# [I 2025-05-23 01:58:33,335] Trial 192 finished with value: -1.019431237858976 and parameters: {'n_estimators': 279, 'learning_rate': 0.005609929380679864, 'max_depth': 4, 'num_leaves': 19, 'subsample': 0.6278696135112531, 'colsample_bytree': 0.6994819709854875, 'min_child_samples': 29, 'reg_alpha': 5.88001809974825, 'reg_lambda': 0.01430142413914074}. Best is trial 105 with value: -1.0186656084721601.
# [I 2025-05-23 01:58:33,957] Trial 193 finished with value: -1.0205050385874483 and parameters: {'n_estimators': 264, 'learning_rate': 0.004860572696465705, 'max_depth': 4, 'num_leaves': 15, 'subsample': 0.6348566793382775, 'colsample_bytree': 0.713114900211707, 'min_child_samples': 30, 'reg_alpha': 9.216045094607743, 'reg_lambda': 0.007525517766791715}. Best is trial 105 with value: -1.0186656084721601.
# [I 2025-05-23 01:58:34,586] Trial 194 finished with value: -1.0194182439570807 and parameters: {'n_estimators': 276, 'learning_rate': 0.005356893563745056, 'max_depth': 4, 'num_leaves': 18, 'subsample': 0.6584399055725406, 'colsample_bytree': 0.6711302054964197, 'min_child_samples': 30, 'reg_alpha': 4.205991996065192, 'reg_lambda': 0.0010189203197229245}. Best is trial 105 with value: -1.0186656084721601.
# [I 2025-05-23 01:58:34,962] Trial 195 finished with value: -1.0226795396379154 and parameters: {'n_estimators': 118, 'learning_rate': 0.004634761586910188, 'max_depth': 4, 'num_leaves': 20, 'subsample': 0.6136810597470754, 'colsample_bytree': 0.6877916236421114, 'min_child_samples': 29, 'reg_alpha': 2.4444419477573844, 'reg_lambda': 0.010017933231370225}. Best is trial 105 with value: -1.0186656084721601.
# [I 2025-05-23 01:58:35,622] Trial 196 finished with value: -1.0200860350177428 and parameters: {'n_estimators': 284, 'learning_rate': 0.005720031414821661, 'max_depth': 4, 'num_leaves': 17, 'subsample': 0.6525887473434367, 'colsample_bytree': 0.6970421945160825, 'min_child_samples': 29, 'reg_alpha': 9.853821761157189, 'reg_lambda': 0.005757863013416964}. Best is trial 105 with value: -1.0186656084721601.
# [I 2025-05-23 01:58:36,215] Trial 197 finished with value: -1.0193723558681025 and parameters: {'n_estimators': 273, 'learning_rate': 0.006003732526578386, 'max_depth': 4, 'num_leaves': 16, 'subsample': 0.673657774651833, 'colsample_bytree': 0.6502435971701643, 'min_child_samples': 30, 'reg_alpha': 3.892239363636948e-06, 'reg_lambda': 0.0032489401074382077}. Best is trial 105 with value: -1.0186656084721601.
# [I 2025-05-23 01:58:36,833] Trial 198 finished with value: -1.0201828157784472 and parameters: {'n_estimators': 262, 'learning_rate': 0.004381733809275201, 'max_depth': 4, 'num_leaves': 19, 'subsample': 0.6366091257059738, 'colsample_bytree': 0.6675645374178244, 'min_child_samples': 29, 'reg_alpha': 3.6186166563857105, 'reg_lambda': 0.0043256956977722905}. Best is trial 105 with value: -1.0186656084721601.
# [I 2025-05-23 01:58:37,531] Trial 199 finished with value: -1.019094784611896 and parameters: {'n_estimators': 335, 'learning_rate': 0.005033007454978026, 'max_depth': 4, 'num_leaves': 22, 'subsample': 0.6017031384263178, 'colsample_bytree': 0.6774162482588874, 'min_child_samples': 30, 'reg_alpha': 0.1878587136658037, 'reg_lambda': 0.015545075739497172}. Best is trial 105 with value: -1.0186656084721601.
# Best trial:
#   Value (Spearman correlation): -1.0187
#   Params:
#     n_estimators: 266
#     learning_rate: 0.006877433950028496
#     max_depth: 4
#     num_leaves: 26
#     subsample: 0.730709856736536
#     colsample_bytree: 0.6546175138047936
#     min_child_samples: 29
#     reg_alpha: 0.1815537849178006
#     reg_lambda: 0.18774253048914655
#
# Cross-validation scores with best model: [-1.07541376 -1.11907527 -1.02548031 -0.8751116  -1.00419994]
# Mean score: -1.0199
# Standard deviation: 0.0827

# %%
{'n_estimators': 200, 'max_depth': 30, 'min_samples_split': 3, 'min_samples_leaf': 5, 'max_features': 'sqrt', 'bootstrap': True}

# %% [markdown]
# # Light GBM

# %%
from lightgbm import LGBMRegressor
from sklearn.model_selection import cross_val_score, KFold
from sklearn.metrics import make_scorer

def spearman_score(y_true, y_pred):
    return spearmanr(y_true, y_pred)[0]

spearman_scorer = make_scorer(spearman_score)

# Define cross-validation strategy
kf = KFold(n_splits=5, shuffle=True, random_state=1)


lgbm_model = LGBMRegressor(
    objective='regression',
    num_leaves=26,
    n_estimators=266,
    max_depth=4,
    subsample=0.730709856736536,
    colsample_bytree=0.6546175138047936,
    learning_rate=0.006877433950028496,
    min_child_samples=29,
    reg_alpha=0.1815537849178006,
    reg_lambda=0.18774253048914655,
    # feature_fraction=0.6,
    # bagging_fraction=0.8,
    # bagging_freq=5,
    random_state=42,
    verbose=-1
)

# n_estimators: 266
#     learning_rate: 0.006877433950028496
#     max_depth: 4
#     num_leaves: 26
#     subsample: 0.730709856736536
#     colsample_bytree: 0.6546175138047936
#     min_child_samples: 29
#     reg_alpha: 0.1815537849178006
#     reg_lambda: 0.18774253048914655

# Cross-validate the model using Spearman correlation
cv_scores = cross_val_score(
    lgbm_model, 
    X_train_features, 
    y_train,
    cv=kf,
    scoring=spearman_scorer
)

print("LightGBM Cross-validation scores (Spearman correlation):", cv_scores)
print("Mean cross-validation score:", cv_scores.mean())
print("Standard deviation of cross-validation scores:", cv_scores.std())

# Train the final model on the full training set
final_lgbm_model = LGBMRegressor(
    objective='regression',
    num_leaves=26,
    n_estimators=266,
    max_depth=4,
    subsample=0.730709856736536,
    colsample_bytree=0.6546175138047936,
    learning_rate=0.006877433950028496,
    min_child_samples=29,
    reg_alpha=0.1815537849178006,
    reg_lambda=0.18774253048914655,
    random_state=42,
    verbose=-1
)

final_lgbm_model.fit(X_train_features, y_train)

# Make predictions on test data
lgbm_predictions = final_lgbm_model.predict(X_test_features)

# Create submission dataframe
lgbm_submission = pd.DataFrame({
    'ID': X_test['ID'],
    'TARGET': lgbm_predictions
})

# Optional: Save submission to CSV
lgbm_submission.to_csv('lightgbm_submission.csv', index=False)

# Feature importance
# plt.figure(figsize=(12, 8))
# lgbm_feature_importance = pd.DataFrame({
#     'Feature': X_train_features.columns,
#     'Importance': final_lgbm_model.feature_importances_
# }).sort_values('Importance', ascending=False)

# plt.barh(lgbm_feature_importance['Feature'], lgbm_feature_importance['Importance'])
# plt.xlabel('Importance')
# plt.title('LightGBM Feature Importance')
# plt.gca().invert_yaxis()
# plt.tight_layout()
# plt.show()
# Out:
# LightGBM Cross-validation scores (Spearman correlation): [0.24288079 0.16328973 0.21299903 0.16421025 0.21291932]
# Mean cross-validation score: 0.19925982596872904
# Standard deviation of cross-validation scores: 0.03098534132369202

# %% [markdown]
# # Catboost

# %%
from catboost import CatBoostRegressor
from sklearn.model_selection import cross_val_score, KFold
from sklearn.metrics import make_scorer
from sklearn.model_selection import RandomizedSearchCV
from scipy.stats import uniform, randint


kf = KFold(n_splits=5, shuffle=True, random_state=42)



# Define CatBoost model
catboost_model = CatBoostRegressor(
    iterations=100,  #utilise 200
    learning_rate=0.029778221049545684,
    depth=4,  #utilise 10
    subsample=0.6924136021544216,
    l2_leaf_reg=5.007455697346183,
    border_count=34,
    random_strength=0.051437686057850714,
    bagging_temperature=0.47359417746471466,
    random_seed=42,
    verbose=False
)


# Cross-validate the model using Spearman correlation
cv_scores = cross_val_score(
    catboost_model, 
    X_train_features, 
    y_train,
    cv=kf,
    scoring=spearman_scorer
)

print("CatBoost Cross-validation scores (Spearman correlation):", cv_scores)
print("Mean cross-validation score:", cv_scores.mean())
print("Standard deviation of cross-validation scores:", cv_scores.std())
# Out:
# CatBoost Cross-validation scores (Spearman correlation): [0.25415008 0.24708131 0.26956706 0.20395629 0.24618625]
# Mean cross-validation score: 0.24418819929526087
# Standard deviation of cross-validation scores: 0.02179125796330315

# %% [markdown]
# Hyperparameters tuning

# %%
# Define parameter grid for CatBoost
param_grid = {
    'iterations': [50, 100, 200],
    'learning_rate': [0.005, 0.01, 0.02],
    'depth': [6, 8, 10],
    'l2_leaf_reg': [2, 3, 4],
    'subsample': [0.7, 0.8, 0.9]
}

# Define cross-validation strategy
kf = KFold(n_splits=5, shuffle=True, random_state=1)

# Create RandomizedSearchCV to find optimal parameters
search = RandomizedSearchCV(
    CatBoostRegressor(random_seed=42, verbose=False),
    param_grid,
    n_iter=100,  # Number of parameter settings sampled
    scoring=spearman_scorer,
    cv=kf,
    random_state=42,
    n_jobs=-1
)

# Fit the model
search.fit(X_train_features, y_train)

# Print best parameters and score
print("Best parameters found:")
print(search.best_params_)
print(f"Best cross-validation score: {search.best_score_:.4f}")
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[16], line 25
#      14 search = RandomizedSearchCV(
#      15     CatBoostRegressor(random_seed=42, verbose=False),
#      16     param_grid,
#    (...)
#      21     n_jobs=-1
#      22 )
#      24 # Fit the model
# ---> 25 search.fit(X_train_features, y_train)
#      27 # Print best parameters and score
#      28 print("Best parameters found:")
#
# File c:\Users\thoma\anaconda3\Lib\site-packages\sklearn\model_selection\_search.py:874, in BaseSearchCV.fit(self, X, y, groups, **fit_params)
#     868     results = self._format_results(
#     869         all_candidate_params, n_splits, all_out, all_more_results
#     870     )
#     872     return results
# --> 874 self._run_search(evaluate_candidates)
#     876 # multimetric is determined here because in the case of a callable
#     877 # self.scoring the return type is only known after calling
#     878 first_test_score = all_out[0]["test_scores"]
#
# File c:\Users\thoma\anaconda3\Lib\site-packages\sklearn\model_selection\_search.py:1768, in RandomizedSearchCV._run_search(self, evaluate_candidates)
#    1766 def _run_search(self, evaluate_candidates):
#    1767     """Search n_iter candidates from param_distributions"""
# -> 1768     evaluate_candidates(
#    1769         ParameterSampler(
#    1770             self.param_distributions, self.n_iter, random_state=self.random_state
#    1771         )
#    1772     )
#
# File c:\Users\thoma\anaconda3\Lib\site-packages\sklearn\model_selection\_search.py:821, in BaseSearchCV.fit.<locals>.evaluate_candidates(candidate_params, cv, more_results)
#     813 if self.verbose > 0:
#     814     print(
#     815         "Fitting {0} folds for each of {1} candidates,"
#     816         " totalling {2} fits".format(
#     817             n_splits, n_candidates, n_candidates * n_splits
#     818         )
#     819     )
# --> 821 out = parallel(
#     822     delayed(_fit_and_score)(
#     823         clone(base_estimator),
#     824         X,
#     825         y,
#     826         train=train,
#     827         test=test,
#     828         parameters=parameters,
#     829         split_progress=(split_idx, n_splits),
#     830         candidate_progress=(cand_idx, n_candidates),
#     831         **fit_and_score_kwargs,
#     832     )
#     833     for (cand_idx, parameters), (split_idx, (train, test)) in product(
#     834         enumerate(candidate_params), enumerate(cv.split(X, y, groups))
#     835     )
#     836 )
#     838 if len(out) < 1:
#     839     raise ValueError(
#     840         "No fits were performed. "
#     841         "Was the CV iterator empty? "
#     842         "Were there no candidates?"
#     843     )
#
# File c:\Users\thoma\anaconda3\Lib\site-packages\sklearn\utils\parallel.py:63, in Parallel.__call__(self, iterable)
#      58 config = get_config()
#      59 iterable_with_config = (
#      60     (_with_config(delayed_func, config), args, kwargs)
#      61     for delayed_func, args, kwargs in iterable
#      62 )
# ---> 63 return super().__call__(iterable_with_config)
#
# File c:\Users\thoma\anaconda3\Lib\site-packages\joblib\parallel.py:1098, in Parallel.__call__(self, iterable)
#    1095     self._iterating = False
#    1097 with self._backend.retrieval_context():
# -> 1098     self.retrieve()
#    1099 # Make sure that we get a last message telling us we are done
#    1100 elapsed_time = time.time() - self._start_time
#
# File c:\Users\thoma\anaconda3\Lib\site-packages\joblib\parallel.py:975, in Parallel.retrieve(self)
#     973 try:
#     974     if getattr(self._backend, 'supports_timeout', False):
# --> 975         self._output.extend(job.get(timeout=self.timeout))
#     976     else:
#     977         self._output.extend(job.get())
#
# File c:\Users\thoma\anaconda3\Lib\site-packages\joblib\_parallel_backends.py:567, in LokyBackend.wrap_future_result(future, timeout)
#     564 """Wrapper for Future.result to implement the same behaviour as
#     565 AsyncResults.get from multiprocessing."""
#     566 try:
# --> 567     return future.result(timeout=timeout)
#     568 except CfTimeoutError as e:
#     569     raise TimeoutError from e
#
# File c:\Users\thoma\anaconda3\Lib\concurrent\futures\_base.py:451, in Future.result(self, timeout)
#     448 elif self._state == FINISHED:
#     449     return self.__get_result()
# --> 451 self._condition.wait(timeout)
#     453 if self._state in [CANCELLED, CANCELLED_AND_NOTIFIED]:
#     454     raise CancelledError()
#
# File c:\Users\thoma\anaconda3\Lib\threading.py:320, in Condition.wait(self, timeout)
#     318 try:    # restore state no matter what (e.g., KeyboardInterrupt)
#     319     if timeout is None:
# --> 320         waiter.acquire()
#     321         gotit = True
#     322     else:
#
# KeyboardInterrupt:

# %%
from catboost import CatBoostRegressor
from sklearn.model_selection import cross_val_score, KFold
from sklearn.metrics import make_scorer
from sklearn.model_selection import RandomizedSearchCV
from scipy.stats import uniform, randint


# Train the final model on the full training set
final_catboost_model = CatBoostRegressor(
    iterations=200,
    learning_rate=0.005,
    depth=10,
    subsample=0.9,
    l2_leaf_reg=4,
    random_seed=42,
    verbose=False
)

final_catboost_model.fit(X_train_features, y_train)

# Make predictions on test data
catboost_predictions = final_catboost_model.predict(X_test_features)



# Create submission dataframe
catboost_submission = pd.DataFrame({
    'ID': X_test['ID'],
    'TARGET': catboost_predictions
})

# Optional: Save submission to CSV
catboost_submission.to_csv('catboost_submission.csv', index=False)

# Feature importance
plt.figure(figsize=(12, 8))
feature_importance = pd.DataFrame({
    'Feature': X_train_features.columns,
    'Importance': final_catboost_model.get_feature_importance()
}).sort_values('Importance', ascending=False)

plt.barh(feature_importance['Feature'], feature_importance['Importance'])
plt.xlabel('Importance')
plt.title('CatBoost Feature Importance')
plt.gca().invert_yaxis()
plt.tight_layout()
plt.show()

# %% [markdown]
# # Random Forest

# %%
from sklearn.ensemble import RandomForestRegressor
from sklearn.model_selection import cross_val_score, KFold
from sklearn.metrics import make_scorer
from sklearn.preprocessing import OneHotEncoder
from scipy.stats import spearmanr


# Define cross-validation strategy
kf = KFold(n_splits=5, shuffle=True, random_state=42)

# Define Random Forest model
rf_model = RandomForestRegressor(
    n_estimators=200,
    max_depth=30,
    min_samples_split=3,
    min_samples_leaf=5,
    max_features='sqrt',
    bootstrap=True,
    random_state=42,
    # n_jobs=-1
)


# Cross-validate the model using Spearman correlation
cv_scores = cross_val_score(
    rf_model, 
    X_train_features, 
    y_train,
    cv=kf,
    scoring=spearman_scorer
)

print("Random Forest Cross-validation scores (Spearman correlation):", cv_scores)
print("Mean cross-validation score:", cv_scores.mean())
print("Standard deviation of cross-validation scores:", cv_scores.std())

# Train the final model on the full training set
# final_rf_model = RandomForestRegressor(
#     n_estimators=1000,
#     max_depth=30,
#     min_samples_split=5,
#     min_samples_leaf=2,
#     random_state=42,
#     n_jobs=-1
# )

# final_rf_model.fit(X_train_features, y_train)

# # Make predictions on test data
# rf_predictions = final_rf_model.predict(X_test_features)

# # Create submission dataframe
# rf_submission = pd.DataFrame({
#     'ID': X_test['ID'],
#     'TARGET': rf_predictions
# })

# # Feature importance
# plt.figure(figsize=(12, 8))
# rf_feature_importance = pd.DataFrame({
#     'Feature': X_train_features.columns,
#     'Importance': final_rf_model.feature_importances_
# }).sort_values('Importance', ascending=False)

# plt.barh(rf_feature_importance['Feature'][:20], rf_feature_importance['Importance'][:20])
# plt.xlabel('Importance')
# plt.title('Random Forest Top 20 Feature Importance')
# plt.gca().invert_yaxis()
# plt.tight_layout()
# plt.show()

# Optional: Save submission to CSV
# rf_submission.to_csv('random_forest_submission.csv', index=False)
# Out:
# Random Forest Cross-validation scores (Spearman correlation): [0.25455761 0.27323289 0.27448357 0.26169753 0.25343099]
# Mean cross-validation score: 0.26348051683876145
# Standard deviation of cross-validation scores: 0.008943896261554916

# %% [markdown]
# # Test features engineering

# %%
from catboost import CatBoostRegressor
from sklearn.model_selection import cross_val_score, KFold
from sklearn.metrics import make_scorer
from sklearn.model_selection import RandomizedSearchCV
from scipy.stats import uniform, randint
import numpy as np
import pandas as pd
from sklearn.linear_model import LinearRegression
from lightgbm import LGBMRegressor
from xgboost import XGBRegressor



kf = KFold(n_splits=5, shuffle=True, random_state=42)



# Define CatBoost model
catboost_model = CatBoostRegressor(
    iterations=100,  #utilise 200
    learning_rate=0.029778221049545684,
    depth=4,  #utilise 10
    subsample=0.6924136021544216,
    l2_leaf_reg=5.007455697346183,
    border_count=34,
    random_strength=0.051437686057850714,
    bagging_temperature=0.47359417746471466,
    random_seed=42,
    verbose=False)

# Cross-validate the model using Spearman correlation
cv_scores = cross_val_score(
    catboost_model, 
    X_train_features, 
    y_train,
    cv=kf,
    scoring=spearman_scorer
)



# Define key variables important for electricity price prediction

# 1. Linear Regression using all features
lin_reg_all = LinearRegression()

lin_reg_all_scores = cross_val_score(
    lin_reg_all, 
    X_train_features, 
    y_train,
    cv=kf,
    scoring=spearman_scorer
)



# 2. Using LightGBM with optimized parameters
lgbm_model_opt = LGBMRegressor(
    objective='regression',
    num_leaves=66,
    n_estimators=395,
    max_depth=11,
    subsample=0.6492490940281487,
    colsample_bytree=0.6691972146849207,
    learning_rate=0.005645533719217677,
    min_child_samples=12,
    reg_alpha=3.230686740318781e-06,
    reg_lambda=1.4073630776519119e-08,
    # feature_fraction=0.6,
    # bagging_fraction=0.8,
    # bagging_freq=5,
    random_state=42
)

lgbm_scores = cross_val_score(
    lgbm_model_opt, 
    X_train_features, 
    y_train,
    cv=kf,
    scoring=spearman_scorer
)
# rf model
rf_model = RandomForestRegressor(
    n_estimators=200,
    max_depth=30,
    min_samples_split=3,
    min_samples_leaf=5,
    max_features='sqrt',
    bootstrap=True,
    random_state=42,
    # n_jobs=-1
)


# Cross-validate the model using Spearman correlation
rf_scores = cross_val_score(
    rf_model, 
    X_train_features, 
    y_train,
    cv=kf,
    scoring=spearman_scorer
)

mean_scores = np.mean([lin_reg_all_scores.mean(), lgbm_scores.mean(), rf_scores.mean(), cv_scores.mean()])


# Print performance metrics
print("\n=== MODEL PERFORMANCE ===")
print(f"Linear Regression (All Features) CV mean score: {lin_reg_all_scores.mean():.4f} ± {lin_reg_all_scores.std():.4f}")
print(f"LightGBM CV mean score: {np.mean(lgbm_scores):.4f} ± {np.std(lgbm_scores):.4f}")
print(f"RF CV mean score: {np.mean(rf_scores):.4f} ± {np.std(rf_scores):.4f}")
print("Mean cross-validation score:", cv_scores.mean())

print("Mean cross-validation score for all models:", mean_scores)
# Out:
# === MODEL PERFORMANCE ===
# Linear Regression (All Features) CV mean score: 0.2434 ± 0.0634
# LightGBM CV mean score: 0.1915 ± 0.0370
# RF CV mean score: 0.2304 ± 0.0552
# Mean cross-validation score: 0.20917648527946833
# Mean cross-validation score for all models: 0.21861554642212225

# %% [markdown]
# # TEst

# %%
from sklearn.linear_model import LinearRegression
import pandas as pd

# # Apply StandardScaler to features
# scaler = StandardScaler()
# X_train_scaled = scaler.fit_transform(X_train_features)
# X_test_scaled = scaler.transform(X_test_features)



# X_train_features = X_train.drop(['COUNTRY'], axis=1).fillna(0)
# X_test_features = X_test.drop(['COUNTRY'], axis=1).fillna(0)

# Train linear regression model
lin_reg = LinearRegression()
lin_reg.fit(X_train_features, y_train)

# Make predictions on test data
lin_reg_predictions = lin_reg.predict(X_test_features)

# Create submission dataframe
lin_reg_submission = pd.DataFrame({
    'ID': X_test['ID'],
    'TARGET': lin_reg_predictions
})

# Save submission to CSV
lin_reg_submission.to_csv('linear_regression_submission.csv', index=False)

print("Linear Regression model trained and submission file created!")
print(f"Preview of submission file:")
print(lin_reg_submission.head())
# Out:
# Linear Regression model trained and submission file created!
# Preview of submission file:
#      ID    TARGET
# 0  1115 -0.016400
# 1  1202  0.076186
# 2  1194 -0.083498
# 3  1084 -0.151095
# 4  1135 -0.074082
